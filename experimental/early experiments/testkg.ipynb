# %%
#%%
import os
import json
from typing import List, Dict, Any, Tuple
import re
from llama_index.extractors.entity import EntityExtractor
from llama_index.core import SimpleDirectoryReader, Document, PropertyGraphIndex
from llama_index.core.graph_stores import SimplePropertyGraphStore
from llama_index.core.settings import Settings
from llama_index.core.storage.storage_context import StorageContext
from llama_index.core.schema import TextNode, NodeRelationship
from llama_index.llms.azure_openai import AzureOpenAI
from llama_index.core.llms import ChatMessage, MessageRole
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from pyvis.network import Network
import nest_asyncio
from langchain_huggingface import HuggingFaceEmbeddings
from llama_index.llms.azure_openai import AzureOpenAI

from dotenv import load_dotenv
load_dotenv()


endpoint = "https://d-ais-eus-ais-chatbots.openai.azure.com/"
model_name = "o1-mini"
deployment = "o1-mini"
subscription_key = os.getenv("AZURE_OPENAI_API_KEY")
api_version = "2024-12-01-preview" # Use a valid API version

llm = AzureOpenAI(
    azure_endpoint=endpoint,
    api_key=subscription_key,
    api_version=api_version,
    deployment_name=deployment,
    model_name=model_name,
    temperature=1.0
)

embed_model=HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

llm2 = AzureOpenAI(
    azure_endpoint=endpoint,
    api_key=subscription_key,
    api_version="2024-05-01-preview",
    deployment_name="gpt-4o-mini-test",
    model_name="gpt-4o-mini-test",
    temperature=1.0
)

#%%
nest_asyncio.apply()

# Load documents
# def load_documents() -> List[Document]:
#     """Load markdown documents from a directory."""
#     reader = SimpleDirectoryReader("./few_examples/").load_data()
#     documents = reader
#     return documents

# documents = SimpleDirectoryReader("./kgdata/").load_data()
documents = SimpleDirectoryReader("./few_examples/").load_data()

# Initialize the graph store
graph_store = SimplePropertyGraphStore()
storage_context = StorageContext.from_defaults(graph_store=graph_store)

# %%
# Add filename and title to metadata for later use as ProtocolDocument properties
processed_documents = []
for doc in documents:
    filename = os.path.basename(doc.metadata.get('file_path', 'unknown.md'))
    # Attempt to extract title from the first line (assuming it's '# Title')
    first_line = doc.text.split('\n', 1)[0]
    title = first_line.lstrip('# ').strip() if first_line.startswith('#') else "Untitled Protocol"
    
    # Create a new Document or update metadata of existing one
    # LlamaIndex expects text in doc.text
    # We will create a ProtocolDocument node explicitly later
    doc.metadata['filename'] = filename
    doc.metadata['protocol_title'] = title
    processed_documents.append(doc)

# %%
processed_documents[0]
# Out:
# Document(id_='f06566ff-7f2b-485f-97c2-8bdd17ff3eb2', embedding=None, metadata={'file_path': 'c:\\Users\\newac\\OneDrive\\Desktop\\Master\\few_examples\\01.md', 'file_name': '01.md', 'file_size': 8702, 'creation_date': '2025-04-30', 'last_modified_date': '2025-04-21', 'filename': '01.md', 'protocol_title': '01 Unconscious adult – not breathing normally'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='# 01 Unconscious adult – not breathing normally\n\n## CRITERIA\n- Critical | Unconscious adult, not breathing normally\n\n## SITUATIONAL GUIDANCE & IMPORTANT TO ASCERTAIN\n- Help is on the way as I speak to you.\n- You must start CPR (reviving the person). I will tell you what to do.\n- Don’t hang up, put the phone on speaker if you can.\n- If there is defibrillator at hand, get someone else to fetch it. Check Hjertestarterregisteret (the caller must not fetch a defibrillator / AED if alone)\n- If you suspect a blocked airway, open the mouth to see if you can remove any object.\n- Are there any children / adolescents present?\n- Are they in need of immediate care or support?\n- Er du usikker på om personen puster normalt: Gi veiledning i sikring av fri luftvei og HLR.\n- Tilby ALLE innringere veiledning, selv om de kan HLR fra før.\n- Gi kontinuerlig veiledning og oppmuntring.\n- Dersom innringer tror personen er død, bør HLR-instruksjoner likevel tilbys, såfremt personen ikke har store skader som er uforenelig med liv.\n- Vær respektfull overfor innringer dersom han/hun mener det ikke er riktig å starte HLR.\n- Hvis personen er gravid i 3. trimester, legg en pute under høyre hofte / korsryggen på personen så hun blir liggende litt over på venstre side.\n- Pasienter utsatt for høyspent strøm: Ikke ta i noen som fortsatt er i kontakt med strømkilde.\n- Se 21 Dødsfall / mulig dødsfall og Legevaktindeks\n\n## EMERGENCY RESPONSE\n\n### SCENARIO\n- Overdose, hanging or other reasons related to breathing.\n- Unconscious adult, not breathing normally\n- BCPR (CARDIO PULMONARY RESUSCITATION)\n- AM I (RESCUER) TRAINED IN CPR?\n\n### IF YES\n- Push down at this rate 30 times.\n- Now give rescue breaths.\n- Tilt the head back with one hand on the forehead.\n- Lift the chin up with the other hand.\n- Pinch the nose and give 2 gentle rescue breaths.\n- Continue with 30 pushes and 2 rescue breaths until medics take over or the person wakes up.\n- 30:2 30:2 30:2\n- Lay the person on the floor, on his / her back.\n- Kneel beside the person’s chest.\n- Place your hands in the middle of his / her chest, kneel right by him / her and keep your elbows straight.\n- Push down hard (with straight elbows) at this rate: 1,2,3,4,5…28,29,30\n- Count aloud with me\n\n### IF NO\n- Keep pushing at this rate until medics take over or the person wakes up.\n- Count to 10 and start again if it’s easier.\n- Lay the person on the floor, on his / her back.\n- Kneel beside the person’s chest.\n- Place your hands in the middle of his / her chest, kneel right by him / her and keep your elbows straight.\n- Push down hard (with straight elbows) at this rate: 1,2,3,4,5…28,29,30\n- Count aloud with me\n\n## EMERGENCY RESPONSE\n\n### SCENARIO\n- Drowning, overdose, hanging or other reasons related to breathing.\n- IS THE PERSON DROWNING?\n\n### IF YES\n- Start giving breaths as quickly as possible, even before the person is out of the water. \n- Chest compressions must be started as soon as it is practically possible.\n- Lay the person on the floor, on his / her back.\n- Kneel beside the person’s chest.\n- Place your hands in the middle of his / her chest, kneel right by him / her and keep your elbows straight.\n- Push down hard ...

# %%
# --- Define Node and Relation Types for the Extractor ---
# This helps guide the LLM. Be as specific as possible.
node_types = [
    "ProtocolDocument", "Criterion", "Advice", "Scenario", "Action",
    "Procedure", "MedicalCondition", "Symptom", "MedicalDevice",
    "Medication", "PatientQualifier", "InformationResource", "Question",
    "InstructionDetail"
]

# Define relationships as (HeadEntityType, RelationType, TailEntityType)
# This is crucial for LLMPropertyGraphExtractor
relation_schemas = [
    ("ProtocolDocument", "HAS_CRITERION", "Criterion"),
    ("ProtocolDocument", "HAS_ADVICE", "Advice"),
    ("Criterion", "TRIGGERS_ADVICE", "Advice"), # Or link via advice_ids
    ("ProtocolDocument", "DEFINES_SCENARIO", "Scenario"),
    ("Scenario", "LEADS_TO_ACTION", "Action"), # Renamed for clarity
    ("Action", "IS_A_PROCEDURE", "Procedure"),
    ("Action", "USES_DEVICE", "MedicalDevice"),
    ("Action", "ADMINISTERS_MEDICATION", "Medication"),
    ("Action", "APPLIES_TO_PATIENT_TYPE", "PatientQualifier"), # Renamed
    ("Procedure", "HAS_INSTRUCTION", "InstructionDetail"), # Renamed
    ("Criterion", "SIGNALS_CONDITION", "MedicalCondition"), # Renamed
    ("Criterion", "PRESENTS_SYMPTOM", "Symptom"), # Renamed
    ("MedicalCondition", "HAS_SYMPTOM", "Symptom"),
    ("MedicalCondition", "MAY_BE_TREATED_WITH", "Procedure"), # Renamed
    ("ProtocolDocument", "CONCERNS_PATIENT_TYPE", "PatientQualifier"), # Renamed
    ("ProtocolDocument", "MENTIONS_RESOURCE", "InformationResource"), # Renamed
    ("ProtocolDocument", "SUGGESTS_QUESTION", "Question"), # Renamed
]

# %%
# --- Advanced CoT Prompting Design ---
kg_extraction_prompt_template = """
You are an expert in medical emergency protocols and knowledge graph generation.
Your task is to extract structured information from the provided text chunk of a medical protocol.
The protocol is titled: "{protocol_title}" from file: "{filename}".

Consider the overall context of this protocol when extracting information.
The main 'ProtocolDocument' node for this text is "{protocol_title}" (filename: "{filename}").
All extracted entities should, where appropriate, be linked to this 'ProtocolDocument' node with a 'PART_OF_PROTOCOL' relationship if no other specific relationship to it is identified.

Allowed Node Types:
{node_types_str}

Allowed Relation Triplets (HeadEntityType, RelationType, TailEntityType):
{relation_schemas_str}

For the given text:
---
{text_chunk}
---

Extract entities and relationships according to the allowed types and schemas.
Entities should have a 'label' (their name or description) and a 'type'.
Extract relevant properties for nodes if they are clearly stated (e.g., 'level' for Criterion, 'advice_id' for Advice).
Relationships should connect two entities with one of the allowed relation types.

Think step by step:
1. Identify potential entities from the text that match the allowed node types. Assign a clear label.
2. For each entity, extract its properties if specified in the schema or clearly available.
3. Identify relationships between these entities based on the allowed relation schemas. Ensure the relationship makes sense in the context of the protocol.
4. Ensure that extracted entities that are components of the protocol are linked to the main 'ProtocolDocument' node for this file ({protocol_title}, {filename}) with a 'PART_OF_PROTOCOL' relationship if no other direct relationship to the ProtocolDocument is identified.

Output the extracted information as a JSON object with two keys: "entities" and "relationships".
"entities": A list of JSON objects, each with "label", "type", and an optional "properties" dictionary.
"relationships": A list of JSON objects, each with "source_label", "relation_label", and "target_label".

Example entity: {{"label": "Start CPR", "type": "Action", "properties": {{"target_patient": "Adult"}}}}
Example relationship: {{"source_label": "Unconscious adult, not breathing normally", "relation_label": "REQUIRES_ATTENTION", "target_label": "Start CPR"}}

"""

# %%
# Format node_types and relation_schemas for the prompt
node_types_str_prompt = "\n".join(f"- {nt}" for nt in node_types)
relation_schemas_str_prompt = "\n".join(f"- ({h}, {r}, {t})" for h, r, t in relation_schemas)

# %%
# Create a list to hold all nodes and relationships from all documents
all_graph_nodes = []
all_graph_relationships = []

# %%
protocol_document_nodes_map = {}
for i, doc in enumerate(processed_documents):
    filename = doc.metadata['filename']
    title = doc.metadata['protocol_title']
    # Use a unique ID for the protocol document node, e.g., filename
    # The label for the node will be its title.
    protocol_node_label = title # This will be the 'label' LLM uses to refer to it
    protocol_document_nodes_map[filename] = protocol_node_label
    
    node_data = {
        "label": protocol_node_label, # What the LLM will use to refer to it
        "type": "ProtocolDocument",
        "properties": {
            "id": filename, # Actual unique ID for the node in the graph
            "filename": filename,
            "title": title
        }
    }
    all_graph_nodes.append(node_data)

# %%
for doc in processed_documents:
    filename = doc.metadata['filename']
    protocol_title = doc.metadata['protocol_title'] # This is the label for the ProtocolDocument node

    # Prepare the specific prompt for this document
    current_prompt = kg_extraction_prompt_template.format(
        protocol_title=protocol_title,
        filename=filename,
        node_types_str=node_types_str_prompt,
        relation_schemas_str=relation_schemas_str_prompt,
        text_chunk=doc.text # Pass the full document text for now
    )

    # Initialize extractor for each document to pass the custom prompt
    # Note: This is a conceptual way. LLMPropertyGraphExtractor might not directly take a fully formatted prompt string
    # but rather a prompt template where it fills {text_chunk}. You might need to subclass or adapt.
    # A more direct way is to make the LLM call yourself and parse its JSON output.

    # Let's try a more direct LLM call for better prompt control
    response = llm.complete(current_prompt)
    llm_output_text = response.text  # Get the raw text from the LLM

    # --- START: Clean the LLM output ---
    cleaned_json_text = llm_output_text.strip()
    if cleaned_json_text.startswith("```json"):
        cleaned_json_text = cleaned_json_text[7:]  # Remove ```json and potential newline
    elif cleaned_json_text.startswith("```"):
        cleaned_json_text = cleaned_json_text[3:]   # Remove ``` and potential newline
    
    if cleaned_json_text.endswith("```"):
        cleaned_json_text = cleaned_json_text[:-3] # Remove trailing ```
    
    cleaned_json_text = cleaned_json_text.strip() # Ensure no leading/trailing whitespace remains
    # --- END: Clean the LLM output ---
    
    try:
        # Now parse the cleaned text
        extracted_data = json.loads(cleaned_json_text) 
        
        for entity in extracted_data.get("entities", []):
            # --- STRIP LABELS ---
            entity["label"] = entity["label"].strip() 
            if "name" in entity: # If you have a separate name field
                entity["name"] = entity["name"].strip()
            # --- END STRIP ---
            entity_id = entity.get("properties", {}).get("id", entity["label"]) 
            if "properties" not in entity: entity["properties"] = {}
            entity["properties"]["id"] = entity_id 
            all_graph_nodes.append(entity)

        for rel in extracted_data.get("relationships", []):
            # --- STRIP LABELS ---
            rel["source_label"] = rel["source_label"].strip()
            rel["target_label"] = rel["target_label"].strip()
            rel["relation_label"] = rel["relation_label"].strip()
            # --- END STRIP ---
            all_graph_relationships.append(rel)
        
        print(f"Cleaned Text Snippet for JSON Parsing: {cleaned_json_text}")
            
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON from LLM for {filename}: {e}")
        print(f"Original LLM Response Snippet: {response.text[:500]}...") 
        print(f"Cleaned Text Snippet for JSON Parsing: {cleaned_json_text[:500]}...")
    except Exception as e:
        print(f"An unexpected error occurred processing {filename}: {e}")
# Out:
# Error decoding JSON from LLM for 01.md: Expecting property name enclosed in double quotes: line 378 column 6 (char 12209)
# Original LLM Response Snippet: ```json
# {
#   "entities": [
#     {
#       "label": "01 Unconscious adult – not breathing normally",
#       "type": "ProtocolDocument",
#       "properties": {
#         "filename": "01.md"
#       }
#     },
#     {
#       "label": "Unconscious adult, not breathing normally",
#       "type": "Criterion",
#       "properties": {
#         "level": "Critical"
#       }
#     },
#     {
#       "label": "Help is on the way as I speak to you.",
#       "type": "Advice"
#     },
#     {
#       "label": "You must start CPR (reviving the ...
# Cleaned Text Snippet for JSON Parsing: {
#   "entities": [
#     {
#       "label": "01 Unconscious adult – not breathing normally",
#       "type": "ProtocolDocument",
#       "properties": {
#         "filename": "01.md"
#       }
#     },
#     {
#       "label": "Unconscious adult, not breathing normally",
#       "type": "Criterion",
#       "properties": {
#         "level": "Critical"
#       }
#     },
#     {
#       "label": "Help is on the way as I speak to you.",
#       "type": "Advice"
#     },
#     {
#       "label": "You must start CPR (reviving the person)....
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[128], line 20
#       6 current_prompt = kg_extraction_prompt_template.format(
#       7     protocol_title=protocol_title,
#       8     filename=filename,
#    (...)     11     text_chunk=doc.text # Pass the full document text for now
#      12 )
#      14 # Initialize extractor for each document to pass the custom prompt
#      15 # Note: This is a conceptual way. LLMPropertyGraphExtractor might not directly take a fully formatted prompt string
#      16 # but rather a prompt template where it fills {text_chunk}. You might need to subclass or adapt.
#      17 # A more direct way is to make the LLM call yourself and parse its JSON output.
#      18
#      19 # Let's try a more direct LLM call for better prompt control
# ---> 20 response = llm.complete(current_prompt)
#      21 llm_output_text = response.text  # Get the raw text from the LLM
#      23 # --- START: Clean the LLM output ---
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:322, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     319             _logger.debug(f"Failed to reset active_span_id: {e}")
#     321 try:
# --> 322     result = func(*args, **kwargs)
#     323     if isinstance(result, asyncio.Future):
#     324         # If the result is a Future, wrap it
#     325         new_future = asyncio.ensure_future(result)
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\core\llms\callbacks.py:431, in llm_completion_callback.<locals>.wrap.<locals>.wrapped_llm_predict(_self, *args, **kwargs)
#     422 event_id = callback_manager.on_event_start(
#     423     CBEventType.LLM,
#     424     payload={
#    (...)    428     },
#     429 )
#     430 try:
# --> 431     f_return_val = f(_self, *args, **kwargs)
#     432 except BaseException as e:
#     433     callback_manager.on_event_end(
#     434         CBEventType.LLM,
#     435         payload={EventPayload.EXCEPTION: e},
#     436         event_id=event_id,
#     437     )
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\llms\openai\base.py:405, in OpenAI.complete(self, prompt, formatted, **kwargs)
#     403 else:
#     404     complete_fn = self._complete
# --> 405 return complete_fn(prompt, **kwargs)
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\core\base\llms\generic_utils.py:179, in chat_to_completion_decorator.<locals>.wrapper(prompt, **kwargs)
#     176 def wrapper(prompt: str, **kwargs: Any) -> CompletionResponse:
#     177     # normalize input
#     178     messages = prompt_to_messages(prompt)
# --> 179     chat_response = func(messages, **kwargs)
#     180     # normalize output
#     181     return chat_response_to_completion_response(chat_response)
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\llms\openai\base.py:111, in llm_retry_decorator.<locals>.wrapper(self, *args, **kwargs)
#     102     return f(self, *args, **kwargs)
#     104 retry = create_retry_decorator(
#     105     max_retries=max_retries,
#     106     random_exponential=True,
#    (...)    109     max_seconds=20,
#     110 )
# --> 111 return retry(f)(self, *args, **kwargs)
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\tenacity\__init__.py:336, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     334 copy = self.copy()
#     335 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336 return copy(f, *args, **kw)
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\tenacity\__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\tenacity\__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\tenacity\__init__.py:398, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     396 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     397     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 398         self._add_action_func(lambda rs: rs.outcome.result())
#     399         return
#     401     if self.after is not None:
#
# File C:\Python312\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File C:\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\tenacity\__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 if isinstance(do, DoAttempt):
#     477     try:
# --> 478         result = fn(*args, **kwargs)
#     479     except BaseException:  # noqa: B902
#     480         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\llms\openai\base.py:476, in OpenAI._chat(self, messages, **kwargs)
#     470 message_dicts = to_openai_message_dicts(
#     471     messages,
#     472     model=self.model,
#     473 )
#     475 if self.reuse_client:
# --> 476     response = client.chat.completions.create(
#     477         messages=message_dicts,
#     478         stream=False,
#     479         **self._get_model_kwargs(**kwargs),
#     480     )
#     481 else:
#     482     with client:
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\openai\_utils\_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:929, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     886 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     887 def create(
#     888     self,
#    (...)    926     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     927 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     928     validate_response_format(response_format)
# --> 929     return self._post(
#     930         "/chat/completions",
#     931         body=maybe_transform(
#     932             {
#     933                 "messages": messages,
#     934                 "model": model,
#     935                 "audio": audio,
#     936                 "frequency_penalty": frequency_penalty,
#     937                 "function_call": function_call,
#     938                 "functions": functions,
#     939                 "logit_bias": logit_bias,
#     940                 "logprobs": logprobs,
#     941                 "max_completion_tokens": max_completion_tokens,
#     942                 "max_tokens": max_tokens,
#     943                 "metadata": metadata,
#     944                 "modalities": modalities,
#     945                 "n": n,
#     946                 "parallel_tool_calls": parallel_tool_calls,
#     947                 "prediction": prediction,
#     948                 "presence_penalty": presence_penalty,
#     949                 "reasoning_effort": reasoning_effort,
#     950                 "response_format": response_format,
#     951                 "seed": seed,
#     952                 "service_tier": service_tier,
#     953                 "stop": stop,
#     954                 "store": store,
#     955                 "stream": stream,
#     956                 "stream_options": stream_options,
#     957                 "temperature": temperature,
#     958                 "tool_choice": tool_choice,
#     959                 "tools": tools,
#     960                 "top_logprobs": top_logprobs,
#     961                 "top_p": top_p,
#     962                 "user": user,
#     963                 "web_search_options": web_search_options,
#     964             },
#     965             completion_create_params.CompletionCreateParamsStreaming
#     966             if stream
#     967             else completion_create_params.CompletionCreateParamsNonStreaming,
#     968         ),
#     969         options=make_request_options(
#     970             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     971         ),
#     972         cast_to=ChatCompletion,
#     973         stream=stream or False,
#     974         stream_cls=Stream[ChatCompletionChunk],
#     975     )
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\openai\_base_client.py:1276, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1262 def post(
#    1263     self,
#    1264     path: str,
#    (...)   1271     stream_cls: type[_StreamT] | None = None,
#    1272 ) -> ResponseT | _StreamT:
#    1273     opts = FinalRequestOptions.construct(
#    1274         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1275     )
# -> 1276     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\openai\_base_client.py:949, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     946 else:
#     947     retries_taken = 0
# --> 949 return self._request(
#     950     cast_to=cast_to,
#     951     options=options,
#     952     stream=stream,
#     953     stream_cls=stream_cls,
#     954     retries_taken=retries_taken,
#     955 )
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\openai\_base_client.py:998, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     995 log.debug("Encountered httpx.TimeoutException", exc_info=True)
#     997 if remaining_retries > 0:
# --> 998     return self._retry_request(
#     999         input_options,
#    1000         cast_to,
#    1001         retries_taken=retries_taken,
#    1002         stream=stream,
#    1003         stream_cls=stream_cls,
#    1004         response_headers=None,
#    1005     )
#    1007 log.debug("Raising timeout error")
#    1008 raise APITimeoutError(request=request) from err
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\openai\_base_client.py:1091, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1087 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1088 # different thread if necessary.
#    1089 time.sleep(timeout)
# -> 1091 return self._request(
#    1092     options=options,
#    1093     cast_to=cast_to,
#    1094     retries_taken=retries_taken + 1,
#    1095     stream=stream,
#    1096     stream_cls=stream_cls,
#    1097 )
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\openai\_base_client.py:998, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     995 log.debug("Encountered httpx.TimeoutException", exc_info=True)
#     997 if remaining_retries > 0:
# --> 998     return self._retry_request(
#     999         input_options,
#    1000         cast_to,
#    1001         retries_taken=retries_taken,
#    1002         stream=stream,
#    1003         stream_cls=stream_cls,
#    1004         response_headers=None,
#    1005     )
#    1007 log.debug("Raising timeout error")
#    1008 raise APITimeoutError(request=request) from err
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\openai\_base_client.py:1091, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1087 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1088 # different thread if necessary.
#    1089 time.sleep(timeout)
# -> 1091 return self._request(
#    1092     options=options,
#    1093     cast_to=cast_to,
#    1094     retries_taken=retries_taken + 1,
#    1095     stream=stream,
#    1096     stream_cls=stream_cls,
#    1097 )
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\openai\_base_client.py:989, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     986 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     988 try:
# --> 989     response = self._client.send(
#     990         request,
#     991         stream=stream or self._should_stream_response_body(request=request),
#     992         **kwargs,
#     993     )
#     994 except httpx.TimeoutException as err:
#     995     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\httpcore\_sync\http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\httpcore\_sync\http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\httpcore\_sync\http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 def read(self, max_bytes: int, timeout: float | None = None) -> bytes:
#     125     exc_map: ExceptionMapping = {socket.timeout: ReadTimeout, OSError: ReadError}
# --> 126     with map_exceptions(exc_map):
#     127         self._sock.settimeout(timeout)
#     128         return self._sock.recv(max_bytes)
#
# File C:\Python312\Lib\contextlib.py:141, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     138     except StopIteration:
#     139         raise RuntimeError("generator didn't yield") from None
# --> 141 def __exit__(self, typ, value, traceback):
#     142     if typ is None:
#     143         try:
#
# KeyboardInterrupt:

# %%
all_graph_nodes
# Out:
# [{'label': '01 Unconscious adult – not breathing normally',
#   'type': 'ProtocolDocument',
#   'properties': {'id': '01.md',
#    'filename': '01.md',
#    'title': '01 Unconscious adult – not breathing normally'}},
#  {'label': '05 Mental health issue',
#   'type': 'ProtocolDocument',
#   'properties': {'id': '05.md',
#    'filename': '05.md',
#    'title': '05 Mental health issue'}},
#  {'label': '23 Poisoning – not related to alcohol or drugs',
#   'type': 'ProtocolDocument',
#   'properties': {'id': '23.md',
#    'filename': '23.md',
#    'title': '23 Poisoning – not related to alcohol or drugs'}},
#  {'label': '01 Unconscious adult – not breathing normally',
#   'type': 'ProtocolDocument',
#   'properties': {'filename': '01.md',
#    'id': '01 Unconscious adult – not breathing normally'}},
#  {'label': 'Critical',
#   'type': 'Criterion',
#   'properties': {'level': 'Critical', 'id': 'Critical'}},
#  {'label': 'Unconscious adult, not breathing normally',
#   'type': 'Symptom',
#   'properties': {'id': 'Unconscious adult, not breathing normally'}},
#  {'label': 'Help is on the way as I speak to you.',
#   'type': 'Advice',
#   'properties': {'id': 'Help is on the way as I speak to you.'}},
#  {'label': 'Start CPR',
#   'type': 'Action',
#   'properties': {'target_patient': 'Adult', 'id': 'Start CPR'}},
#  {'label': 'Defibrillator',
#   'type': 'MedicalDevice',
#   'properties': {'id': 'Defibrillator'}},
#  {'label': 'Hjertestarterregisteret',
#   'type': 'InformationResource',
#   'properties': {'id': 'Hjertestarterregisteret'}},
#  {'label': 'Blocked airway',
#   'type': 'MedicalCondition',
#   'properties': {'id': 'Blocked airway'}},
#  {'label': 'Children / adolescents present',
#   'type': 'Question',
#   'properties': {'id': 'Children / adolescents present'}},
#  {'label': 'Immediate care or support needed',
#   'type': 'Question',
#   'properties': {'id': 'Immediate care or support needed'}},
#  {'label': 'Rescuing a pregnant person in the 3rd trimester',
#   'type': 'PatientQualifier',
#   'properties': {'id': 'Rescuing a pregnant person in the 3rd trimester'}},
#  {'label': 'High voltage electrical exposure',
#   'type': 'MedicalCondition',
#   'properties': {'id': 'High voltage electrical exposure'}},
#  {'label': 'Drowning',
#   'type': 'MedicalCondition',
#   'properties': {'id': 'Drowning'}},
#  {'label': 'Overdose',
#   'type': 'MedicalCondition',
#   'properties': {'id': 'Overdose'}},
#  {'label': 'Hanging',
#   'type': 'MedicalCondition',
#   'properties': {'id': 'Hanging'}},
#  {'label': 'Cardio Pulmonary Resuscitation (CPR)',
#   'type': 'Procedure',
#   'properties': {'id': 'Cardio Pulmonary Resuscitation (CPR)'}},
#  {'label': 'Chest compressions',
#   'type': 'InstructionDetail',
#   'properties': {'id': 'Chest compressions'}},
#  {'label': 'Rescue breaths',
#   'type': 'InstructionDetail',
#   'properties': {'id': 'Rescue breaths'}},
#  {'label': 'AED (Automated External Defibrillator)',
#   'type': 'MedicalDevice',
#   'properties': {'id': 'AED (Automated External Defibrillator)'}},
#  {'label': 'ROSC (Return of Spontaneous Circulation)',
#   'type': 'MedicalCondition',
#   'properties': {'id': 'ROSC (Return of Spontaneous Circulation)'}},
#  {'label': 'Ischemic heart disease',
#   'type': 'MedicalCondition',
#   'properties': {'id': 'Ischemic heart disease'}},
#  {'label': 'Agonal breath',
#   'type': 'Symptom',
#   'properties': {'id': 'Agonal breath'}},
#  {'label': 'Speakerphone usage',
#   'type': 'InstructionDetail',
#   'properties': {'id': 'Speakerphone usage'}},
#  {'label': 'Metronome for chest compressions',
#   'type': 'MedicalDevice',
#   'properties': {'id': 'Metronome for chest compressions'}},
#  {'label': 'HLR-instruksjoner',
#   'type': 'Procedure',
#   'properties': {'id': 'HLR-instruksjoner'}},
#  {'label': 'Sedation and stabilization assistance',
#   'type': 'Procedure',
#   'properties': {'id': 'Sedation and stabilization assistance'}},
#  {'label': 'Defibrillation',
#   'type': 'Procedure',
#   'properties': {'id': 'Defibrillation'}},
#  {'label': 'Terminally ill patient decision',
#   'type': 'Question',
#   'properties': {'id': 'Terminally ill patient decision'}},
#  {'label': 'Neonatal presence',
#   'type': 'Question',
#   'properties': {'id': 'Neonatal presence'}},
#  {'label': '05 Mental health issue',
#   'type': 'ProtocolDocument',
#   'properties': {'filename': '05.md', 'id': '05 Mental health issue'}},
#  {'label': 'Very restless (troubled, agitated). In immediate or imminent danger to self or others',
#   'type': 'Criterion',
#   'properties': {'level': 'Critical',
#    'code': '1.2.3.4',
#    'id': 'Very restless (troubled, agitated). In immediate or imminent danger to self or others'}},
#  {'label': 'Aggressive, threatening behaviour. In immediate or imminent danger to self or others',
#   'type': 'Criterion',
#   'properties': {'level': 'Critical',
#    'code': '1.2.3.4',
#    'id': 'Aggressive, threatening behaviour. In immediate or imminent danger to self or others'}},
#  {'label': 'Increasing anxiety',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent',
#    'code': '2.3.4',
#    'id': 'Increasing anxiety'}},
#  {'label': 'Increasing restlessness and/or confusion',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent',
#    'code': '2.3.4',
#    'id': 'Increasing restlessness and/or confusion'}},
#  {'label': 'Visual and/or auditory (hearing) hallucinations',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent',
#    'code': '2.3.4',
#    'id': 'Visual and/or auditory (hearing) hallucinations'}},
#  {'label': 'Verbal threats',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent', 'code': '2.3.4', 'id': 'Verbal threats'}},
#  {'label': 'Threat of violence',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent',
#    'code': '2.3.4',
#    'id': 'Threat of violence'}},
#  {'label': 'Indifferent (disinterested) or major mood swings',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent',
#    'code': '2.3.4',
#    'id': 'Indifferent (disinterested) or major mood swings'}},
#  {'label': 'Caller needs assistance',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent',
#    'code': '2.3.4',
#    'id': 'Caller needs assistance'}},
#  {'label': 'Change in behaviour or mood, does not have a known mental health problem',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent',
#    'code': '2.3.4',
#    'id': 'Change in behaviour or mood, does not have a known mental health problem'}},
#  {'label': 'Known mental health issue, several calls, probably needs medical assistance',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent',
#    'code': '2.3.4',
#    'id': 'Known mental health issue, several calls, probably needs medical assistance'}},
#  {'label': 'Other symptoms related to this page',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent',
#    'code': '2.3.4',
#    'id': 'Other symptoms related to this page'}},
#  {'label': 'Report of concern. Behaving strangely, but is quiet and under control',
#   'type': 'Criterion',
#   'properties': {'level': 'Normal',
#    'code': 'LVI',
#    'id': 'Report of concern. Behaving strangely, but is quiet and under control'}},
#  {'label': 'Feeling low and inert (listless)',
#   'type': 'Criterion',
#   'properties': {'level': 'Normal',
#    'code': 'LVI',
#    'id': 'Feeling low and inert (listless)'}},
#  {'label': 'Wants to talk to a doctor or others who can help',
#   'type': 'Criterion',
#   'properties': {'level': 'Normal',
#    'code': 'LVI',
#    'id': 'Wants to talk to a doctor or others who can help'}},
#  {'label': 'Frequent caller without any new problems, known mental health issue',
#   'type': 'Criterion',
#   'properties': {'level': 'Normal',
#    'code': 'LVI',
#    'id': 'Frequent caller without any new problems, known mental health issue'}},
#  {'label': 'Other, not urgent',
#   'type': 'Criterion',
#   'properties': {'level': 'Normal', 'code': 'LVI', 'id': 'Other, not urgent'}},
#  {'label': 'IMPORTANT INFORMATION TO THE CALLER',
#   'type': 'Advice',
#   'properties': {'advice_id': '1',
#    'id': 'IMPORTANT INFORMATION TO THE CALLER'}},
#  {'label': 'MEDICATION',
#   'type': 'Advice',
#   'properties': {'advice_id': '2', 'id': 'MEDICATION'}},
#  {'label': 'RESTLESS / AGGRESSIVE PERSON',
#   'type': 'Advice',
#   'properties': {'advice_id': '3', 'id': 'RESTLESS / AGGRESSIVE PERSON'}},
#  {'label': 'IF RELEVANT:',
#   'type': 'Advice',
#   'properties': {'advice_id': '4', 'id': 'IF RELEVANT:'}},
#  {'label': 'Are there any children / adolescents present? Are they in need of immediate care or support?',
#   'type': 'Question',
#   'properties': {'id': 'Are there any children / adolescents present? Are they in need of immediate care or support?'}},
#  {'label': 'Are there any animals that need to be looked after?',
#   'type': 'Question',
#   'properties': {'id': 'Are there any animals that need to be looked after?'}},
#  {'label': 'Do you know if the person has a mental health crisis plan? If so – where is it?',
#   'type': 'Question',
#   'properties': {'id': 'Do you know if the person has a mental health crisis plan? If so – where is it?'}},
#  {'label': 'How does s/he seem now? How does s/he answer your questions?',
#   'type': 'Question',
#   'properties': {'id': 'How does s/he seem now? How does s/he answer your questions?'}},
#  {'label': 'Do you know what s/he has taken, and when?',
#   'type': 'Question',
#   'properties': {'id': 'Do you know what s/he has taken, and when?'}},
#  {'label': 'When did it start to get worse? What can have triggered this?',
#   'type': 'Question',
#   'properties': {'id': 'When did it start to get worse? What can have triggered this?'}},
#  {'label': 'Where has s/he been treated? When?',
#   'type': 'Question',
#   'properties': {'id': 'Where has s/he been treated? When?'}},
#  {'label': 'Is s/he being followed up by a primary health care team?',
#   'type': 'Question',
#   'properties': {'id': 'Is s/he being followed up by a primary health care team?'}},
#  {'label': 'When did things start to change? What can have triggered this?',
#   'type': 'Question',
#   'properties': {'id': 'When did things start to change? What can have triggered this?'}},
#  {'label': 'How long has s/he (name) been ill?',
#   'type': 'Question',
#   'properties': {'id': 'How long has s/he (name) been ill?'}},
#  {'label': 'How does s/he feel about you calling us (AMK/LVS)? Is it ok or not?',
#   'type': 'Question',
#   'properties': {'id': 'How does s/he feel about you calling us (AMK/LVS)? Is it ok or not?'}},
#  {'label': 'Who else is present?',
#   'type': 'Question',
#   'properties': {'id': 'Who else is present?'}},
#  {'label': 'Are they safe?',
#   'type': 'Question',
#   'properties': {'id': 'Are they safe?'}},
#  {'label': 'Are there any dangerous items they can get hold of?',
#   'type': 'Question',
#   'properties': {'id': 'Are there any dangerous items they can get hold of?'}},
#  {'label': 'Is anyone else expected to arrive soon (children, other people with similar problems?)',
#   'type': 'Question',
#   'properties': {'id': 'Is anyone else expected to arrive soon (children, other people with similar problems?)'}},
#  {'label': 'How is the person coping? Are there any changes in personal care (is there enough food in the fridge, is personal hygiene ok, is the home clean etc.)',
#   'type': 'Question',
#   'properties': {'id': 'How is the person coping? Are there any changes in personal care (is there enough food in the fridge, is personal hygiene ok, is the home clean etc.)'}},
#  {'label': 'Clarify BVC status in the event of aggressive, threatening or violent behaviour.',
#   'type': 'Procedure',
#   'properties': {'id': 'Clarify BVC status in the event of aggressive, threatening or violent behaviour.'}},
#  {'label': 'BRØSET violence checklist',
#   'type': 'Procedure',
#   'properties': {'id': 'BRØSET violence checklist'}},
#  {'label': 'Medication must accompany the person',
#   'type': 'Medication',
#   'properties': {'id': 'Medication must accompany the person'}},
#  {'label': 'UKOM report "Somatisk helse hos pasienter med alvorlig psykisk lidelse"',
#   'type': 'InformationResource',
#   'properties': {'id': 'UKOM report "Somatisk helse hos pasienter med alvorlig psykisk lidelse"'}},
#  {'label': 'Mental Health Crisis Plan',
#   'type': 'MedicalCondition',
#   'properties': {'id': 'Mental Health Crisis Plan'}},
#  {'label': 'Psychosis',
#   'type': 'MedicalCondition',
#   'properties': {'id': 'Psychosis'}},
#  {'label': 'Panic Anxiety',
#   'type': 'MedicalCondition',
#   'properties': {'id': 'Panic Anxiety'}},
#  {'label': 'Somatic Illness',
#   'type': 'MedicalCondition',
#   'properties': {'id': 'Somatic Illness'}},
#  {'label': 'Increasing anxiety',
#   'type': 'Symptom',
#   'properties': {'id': 'Increasing anxiety'}},
#  {'label': 'Increasing restlessness',
#   'type': 'Symptom',
#   'properties': {'id': 'Increasing restlessness'}},
#  {'label': 'Confusion', 'type': 'Symptom', 'properties': {'id': 'Confusion'}},
#  {'label': 'Visual hallucinations',
#   'type': 'Symptom',
#   'properties': {'id': 'Visual hallucinations'}},
#  {'label': 'Auditory hallucinations',
#   'type': 'Symptom',
#   'properties': {'id': 'Auditory hallucinations'}},
#  {'label': 'Verbal threats',
#   'type': 'Symptom',
#   'properties': {'id': 'Verbal threats'}},
#  {'label': 'Threat of violence',
#   'type': 'Symptom',
#   'properties': {'id': 'Threat of violence'}},
#  {'label': 'Indifference',
#   'type': 'Symptom',
#   'properties': {'id': 'Indifference'}},
#  {'label': 'Major mood swings',
#   'type': 'Symptom',
#   'properties': {'id': 'Major mood swings'}},
#  {'label': 'Restlessness',
#   'type': 'Symptom',
#   'properties': {'id': 'Restlessness'}},
#  {'label': 'Aggressive behaviour',
#   'type': 'Symptom',
#   'properties': {'id': 'Aggressive behaviour'}},
#  {'label': 'Query on Change in mental state',
#   'type': 'Question',
#   'properties': {'id': 'Query on Change in mental state'}},
#  {'label': 'SAMTYKKEKOMPETANSE',
#   'type': 'InformationResource',
#   'properties': {'id': 'SAMTYKKEKOMPETANSE'}},
#  {'label': '23 Poisoning – not related to alcohol or drugs',
#   'type': 'ProtocolDocument',
#   'properties': {'id': '23 Poisoning – not related to alcohol or drugs'}},
#  {'label': 'Critical | Unconscious (unresponsive)',
#   'type': 'Criterion',
#   'properties': {'level': 'Critical',
#    'code': '1.2.9',
#    'id': 'Critical | Unconscious (unresponsive)'}},
#  {'label': 'Critical | May have ingested a potentially dangerous amount of a toxic substance',
#   'type': 'Criterion',
#   'properties': {'level': 'Critical',
#    'id': 'Critical | May have ingested a potentially dangerous amount of a toxic substance'}},
#  {'label': 'Critical | May have ingested a potentially dangerous amount of a toxic substance - Is having a seizure (convulsion, fit)',
#   'type': 'Criterion',
#   'properties': {'level': 'Critical',
#    'code': '1.2.3.9.10',
#    'id': 'Critical | May have ingested a potentially dangerous amount of a toxic substance - Is having a seizure (convulsion, fit)'}},
#  {'label': 'Critical | May have ingested a potentially dangerous amount of a toxic substance - Serious or continuing airway symptoms',
#   'type': 'Criterion',
#   'properties': {'level': 'Critical',
#    'code': '1.2.4.9.10',
#    'id': 'Critical | May have ingested a potentially dangerous amount of a toxic substance - Serious or continuing airway symptoms'}},
#  {'label': 'Critical | May have ingested a potentially dangerous amount of a toxic substance - Pale, clammy skin (cold sweating)',
#   'type': 'Criterion',
#   'properties': {'level': 'Critical',
#    'code': '1.2.6.9.10',
#    'id': 'Critical | May have ingested a potentially dangerous amount of a toxic substance - Pale, clammy skin (cold sweating)'}},
#  {'label': 'Critical | May have ingested a potentially dangerous amount of a toxic substance - Difficulty swallowing',
#   'type': 'Criterion',
#   'properties': {'level': 'Critical',
#    'code': '1.2.4.9.10',
#    'id': 'Critical | May have ingested a potentially dangerous amount of a toxic substance - Difficulty swallowing'}},
#  {'label': 'Critical | May have ingested a potentially dangerous amount of a toxic substance - Immediate treatment required to avoid serious symptoms or injury',
#   'type': 'Criterion',
#   'properties': {'level': 'Critical',
#    'code': '1.2.9.10',
#    'id': 'Critical | May have ingested a potentially dangerous amount of a toxic substance - Immediate treatment required to avoid serious symptoms or injury'}},
#  {'label': 'Critical | May have ingested a potentially dangerous amount of a toxic substance - Has swallowed a battery with symptoms',
#   'type': 'Criterion',
#   'properties': {'level': 'Critical',
#    'code': '1.2.9.10',
#    'id': 'Critical | May have ingested a potentially dangerous amount of a toxic substance - Has swallowed a battery with symptoms'}},
#  {'label': 'Critical | May have ingested a corrosive substance causing swallowing difficulties',
#   'type': 'Criterion',
#   'properties': {'level': 'Critical',
#    'code': '1.2.7.9.10',
#    'id': 'Critical | May have ingested a corrosive substance causing swallowing difficulties'}},
#  {'label': 'Urgent | May have ingested a potentially dangerous amount of a toxic substance (RED response)',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent',
#    'code': '7.8.9',
#    'id': 'Urgent | May have ingested a potentially dangerous amount of a toxic substance (RED response)'}},
#  {'label': 'Urgent | May have ingested a corrosive substance without airway symptoms',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent',
#    'code': '7.9',
#    'id': 'Urgent | May have ingested a corrosive substance without airway symptoms'}},
#  {'label': 'Urgent | Ingested an oil-based or petroleum product without cough',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent',
#    'code': '8.9',
#    'id': 'Urgent | Ingested an oil-based or petroleum product without cough'}},
#  {'label': 'Urgent | Suspect self-inflicted injury or neglect',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent',
#    'code': '2.9',
#    'id': 'Urgent | Suspect self-inflicted injury or neglect'}},
#  {'label': 'Urgent | Other symptoms related to this page',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent',
#    'code': '2.9',
#    'id': 'Urgent | Other symptoms related to this page'}},
#  {'label': 'Normal | May have ingested a small amount of a toxic substance, no symptoms',
#   'type': 'Criterion',
#   'properties': {'level': 'Normal',
#    'code': 'LVI',
#    'id': 'Normal | May have ingested a small amount of a toxic substance, no symptoms'}},
#  {'label': 'Normal | Other, not urgent',
#   'type': 'Criterion',
#   'properties': {'level': 'Normal',
#    'code': 'LVI',
#    'id': 'Normal | Other, not urgent'}},
#  {'label': 'IMPORTANT INFORMATION TO THE CALLER',
#   'type': 'Advice',
#   'properties': {'advice_id': 1, 'id': 'IMPORTANT INFORMATION TO THE CALLER'}},
#  {'label': 'SAFETY AT THE SCENE',
#   'type': 'Advice',
#   'properties': {'advice_id': 2, 'id': 'SAFETY AT THE SCENE'}},
#  {'label': 'UNRESPONSIVE / CONVULSIONS',
#   'type': 'Advice',
#   'properties': {'advice_id': 3, 'id': 'UNRESPONSIVE / CONVULSIONS'}},
#  {'label': 'DIFFICULTY BREATHING',
#   'type': 'Advice',
#   'properties': {'advice_id': 4, 'id': 'DIFFICULTY BREATHING'}},
#  {'label': 'DIFFICULT TO WAKE, DROWSY, SLEEPY (altered level of consciousness)',
#   'type': 'Advice',
#   'properties': {'advice_id': 5,
#    'id': 'DIFFICULT TO WAKE, DROWSY, SLEEPY (altered level of consciousness)'}},
#  {'label': 'PALE, CLAMMY SKIN',
#   'type': 'Advice',
#   'properties': {'advice_id': 6, 'id': 'PALE, CLAMMY SKIN'}},
#  {'label': 'CORROSIVES IN THE MOUTH / THROAT',
#   'type': 'Advice',
#   'properties': {'advice_id': 7, 'id': 'CORROSIVES IN THE MOUTH / THROAT'}},
#  {'label': 'HAS INGESTED A PETROLEUMBASED PRODUCT',
#   'type': 'Advice',
#   'properties': {'advice_id': 8,
#    'id': 'HAS INGESTED A PETROLEUMBASED PRODUCT'}},
#  {'label': 'KEEP ALL PACKAGING',
#   'type': 'Advice',
#   'properties': {'advice_id': 9, 'id': 'KEEP ALL PACKAGING'}},
#  {'label': 'MEDICATION',
#   'type': 'Advice',
#   'properties': {'advice_id': 10, 'id': 'MEDICATION'}},
#  {'label': 'Unconscious',
#   'type': 'Symptom',
#   'properties': {'id': 'Unconscious'}},
#  {'label': 'Seizure (convulsion, fit)',
#   'type': 'Symptom',
#   'properties': {'id': 'Seizure (convulsion, fit)'}},
#  {'label': 'Serious or continuing airway symptoms',
#   'type': 'Symptom',
#   'properties': {'id': 'Serious or continuing airway symptoms'}},
#  {'label': 'Pale, clammy skin (cold sweating)',
#   'type': 'Symptom',
#   'properties': {'id': 'Pale, clammy skin (cold sweating)'}},
#  {'label': 'Difficulty swallowing',
#   'type': 'Symptom',
#   'properties': {'id': 'Difficulty swallowing'}},
#  {'label': 'Immediate treatment required',
#   'type': 'MedicalCondition',
#   'properties': {'id': 'Immediate treatment required'}},
#  {'label': 'Swallowed battery',
#   'type': 'MedicalCondition',
#   'properties': {'id': 'Swallowed battery'}},
#  {'label': 'Ingested corrosive substance causing swallowing difficulties',
#   'type': 'MedicalCondition',
#   'properties': {'id': 'Ingested corrosive substance causing swallowing difficulties'}},
#  {'label': 'Corrosives in the mouth/throat',
#   'type': 'MedicalDevice',
#   'properties': {'id': 'Corrosives in the mouth/throat'}},
#  {'label': 'Petroleum-based product ingestion',
#   'type': 'MedicalCondition',
#   'properties': {'id': 'Petroleum-based product ingestion'}},
#  {'label': 'Medication being used by the person',
#   'type': 'Medication',
#   'properties': {'id': 'Medication being used by the person'}},
#  {'label': '01 Unconscious adult – not breathing normally',
#   'type': 'ProtocolDocument',
#   'properties': {'filename': '01.md',
#    'id': '01 Unconscious adult – not breathing normally'}},
#  {'label': 'Critical | Unconscious adult, not breathing normally',
#   'type': 'Criterion',
#   'properties': {'level': 'Critical',
#    'id': 'Critical | Unconscious adult, not breathing normally'}},
#  {'label': 'Help is on the way as I speak to you.',
#   'type': 'Advice',
#   'properties': {'id': 'Help is on the way as I speak to you.'}},
#  {'label': 'You must start CPR (reviving the person). I will tell you what to do.',
#   'type': 'Advice',
#   'properties': {'id': 'You must start CPR (reviving the person). I will tell you what to do.'}},
#  {'label': 'Don’t hang up, put the phone on speaker if you can.',
#   'type': 'Advice',
#   'properties': {'id': 'Don’t hang up, put the phone on speaker if you can.'}},
#  {'label': 'If there is defibrillator at hand, get someone else to fetch it.',
#   'type': 'Advice',
#   'properties': {'id': 'If there is defibrillator at hand, get someone else to fetch it.'}},
#  {'label': 'Check Hjertestarterregisteret',
#   'type': 'Advice',
#   'properties': {'id': 'Check Hjertestarterregisteret'}},
#  {'label': 'If you suspect a blocked airway, open the mouth to see if you can remove any object.',
#   'type': 'Advice',
#   'properties': {'id': 'If you suspect a blocked airway, open the mouth to see if you can remove any object.'}},
#  {'label': 'Are there any children / adolescents present?',
#   'type': 'Question',
#   'properties': {'id': 'Are there any children / adolescents present?'}},
#  {'label': 'Are they in need of immediate care or support?',
#   'type': 'Question',
#   'properties': {'id': 'Are they in need of immediate care or support?'}},
#  {'label': 'Gi veiledning i sikring av fri luftvei og HLR.',
#   'type': 'Advice',
#   'properties': {'id': 'Gi veiledning i sikring av fri luftvei og HLR.'}},
#  {'label': 'Tilby ALLE innringere veiledning, selv om de kan HLR fra før.',
#   'type': 'Advice',
#   'properties': {'id': 'Tilby ALLE innringere veiledning, selv om de kan HLR fra før.'}},
#  {'label': 'Gi kontinuerlig veiledning og oppmuntring.',
#   'type': 'Advice',
#   'properties': {'id': 'Gi kontinuerlig veiledning og oppmuntring.'}},
#  {'label': 'HLR-instruksjoner likevel tilbys',
#   'type': 'Advice',
#   'properties': {'id': 'HLR-instruksjoner likevel tilbys'}},
#  {'label': 'Vær respektfull overfor innringer',
#   'type': 'Advice',
#   'properties': {'id': 'Vær respektfull overfor innringer'}},
#  {'label': 'Legg en pute under høyre hofte / korsryggen på personen',
#   'type': 'Advice',
#   'properties': {'id': 'Legg en pute under høyre hofte / korsryggen på personen'}},
#  {'label': 'Ikke ta i noen som fortsatt er i kontakt med strømkilde.',
#   'type': 'Advice',
#   'properties': {'id': 'Ikke ta i noen som fortsatt er i kontakt med strømkilde.'}},
#  {'label': 'Se 21 Dødsfall / mulig dødsfall og Legevaktindeks',
#   'type': 'InformationResource',
#   'properties': {'id': 'Se 21 Dødsfall / mulig dødsfall og Legevaktindeks'}},
#  {'label': 'Overdose, hanging or other reasons related to breathing.',
#   'type': 'Scenario',
#   'properties': {'id': 'Overdose, hanging or other reasons related to breathing.'}},
#  {'label': 'Drowning, overdose, hanging or other reasons related to breathing.',
#   'type': 'Scenario',
#   'properties': {'id': 'Drowning, overdose, hanging or other reasons related to breathing.'}},
#  {'label': 'Is there an AED at hand?',
#   'type': 'Question',
#   'properties': {'id': 'Is there an AED at hand?'}},
#  {'label': 'CARDIO PULMONARY RESUSCITATION',
#   'type': 'Procedure',
#   'properties': {'id': 'CARDIO PULMONARY RESUSCITATION'}},
#  {'label': 'Start CPR', 'type': 'Action', 'properties': {'id': 'Start CPR'}},
#  {'label': 'Push down at this rate 30 times.',
#   'type': 'Action',
#   'properties': {'id': 'Push down at this rate 30 times.'}},
#  {'label': 'Give rescue breaths.',
#   'type': 'Action',
#   'properties': {'id': 'Give rescue breaths.'}},
#  {'label': 'Tilt the head back with one hand on the forehead.',
#   'type': 'InstructionDetail',
#   'properties': {'id': 'Tilt the head back with one hand on the forehead.'}},
#  {'label': 'Lift the chin up with the other hand.',
#   'type': 'InstructionDetail',
#   'properties': {'id': 'Lift the chin up with the other hand.'}},
#  {'label': 'Pinch the nose and give 2 gentle rescue breaths.',
#   'type': 'InstructionDetail',
#   'properties': {'id': 'Pinch the nose and give 2 gentle rescue breaths.'}},
#  {'label': 'Lay the person on the floor, on his / her back.',
#   'type': 'Action',
#   'properties': {'id': 'Lay the person on the floor, on his / her back.'}},
#  {'label': 'Kneel beside the person’s chest.',
#   'type': 'InstructionDetail',
#   'properties': {'id': 'Kneel beside the person’s chest.'}},
#  {'label': 'Place your hands in the middle of his / her chest, keep your elbows straight.',
#   'type': 'InstructionDetail',
#   'properties': {'id': 'Place your hands in the middle of his / her chest, keep your elbows straight.'}},
#  {'label': 'Push down hard at a rate of 100 per minute.',
#   'type': 'InstructionDetail',
#   'properties': {'id': 'Push down hard at a rate of 100 per minute.'}},
#  {'label': 'Defibrillation',
#   'type': 'Procedure',
#   'properties': {'id': 'Defibrillation'}},
#  {'label': 'AED', 'type': 'MedicalDevice', 'properties': {'id': 'AED'}},
#  {'label': 'Defibrillator',
#   'type': 'MedicalDevice',
#   'properties': {'id': 'Defibrillator'}},
#  {'label': 'Pregnant in 3rd trimester',
#   'type': 'PatientQualifier',
#   'properties': {'id': 'Pregnant in 3rd trimester'}},
#  {'label': 'Adult', 'type': 'PatientQualifier', 'properties': {'id': 'Adult'}},
#  {'label': 'Hjertestarterregisteret',
#   'type': 'InformationResource',
#   'properties': {'id': 'Hjertestarterregisteret'}},
#  {'label': 'Legevaktindeks',
#   'type': 'InformationResource',
#   'properties': {'id': 'Legevaktindeks'}},
#  {'label': 'Rozygcirculation restored (ROSC)',
#   'type': 'MedicalCondition',
#   'properties': {'id': 'Rozygcirculation restored (ROSC)'}},
#  {'label': 'Ischemic heart disease',
#   'type': 'MedicalCondition',
#   'properties': {'id': 'Ischemic heart disease'}},
#  {'label': 'Agonal breathing',
#   'type': 'Symptom',
#   'properties': {'id': 'Agonal breathing'}},
#  {'label': 'Blocked airway',
#   'type': 'Symptom',
#   'properties': {'id': 'Blocked airway'}},
#  {'label': '05 Mental health issue',
#   'type': 'ProtocolDocument',
#   'properties': {'filename': '05.md', 'id': '05 Mental health issue'}},
#  {'label': 'Very restless (troubled, agitated). In immediate or imminent danger to self or others',
#   'type': 'Criterion',
#   'properties': {'level': 'Critical',
#    'code': '1.2.3.4',
#    'id': 'Very restless (troubled, agitated). In immediate or imminent danger to self or others'}},
#  {'label': 'Aggressive, threatening behaviour. In immediate or imminent danger to self or others',
#   'type': 'Criterion',
#   'properties': {'level': 'Critical',
#    'code': '1.2.3.4',
#    'id': 'Aggressive, threatening behaviour. In immediate or imminent danger to self or others'}},
#  {'label': 'Increasing anxiety',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent',
#    'code': '2.3.4',
#    'id': 'Increasing anxiety'}},
#  {'label': 'Increasing restlessness and/or confusion',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent',
#    'code': '2.3.4',
#    'id': 'Increasing restlessness and/or confusion'}},
#  {'label': 'Visual and/or auditory (hearing) hallucinations',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent',
#    'code': '2.3.4',
#    'id': 'Visual and/or auditory (hearing) hallucinations'}},
#  {'label': 'Verbal threats',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent', 'code': '2.3.4', 'id': 'Verbal threats'}},
#  {'label': 'Threat of violence',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent',
#    'code': '2.3.4',
#    'id': 'Threat of violence'}},
#  {'label': 'Indifferent (disinterested) or major mood swings',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent',
#    'code': '2.3.4',
#    'id': 'Indifferent (disinterested) or major mood swings'}},
#  {'label': 'Caller needs assistance',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent',
#    'code': '2.3.4',
#    'id': 'Caller needs assistance'}},
#  {'label': 'Change in behaviour or mood, does not have a known mental health problem',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent',
#    'code': '2.3.4',
#    'id': 'Change in behaviour or mood, does not have a known mental health problem'}},
#  {'label': 'Known mental health issue, several calls, probably needs medical assistance',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent',
#    'code': '2.3.4',
#    'id': 'Known mental health issue, several calls, probably needs medical assistance'}},
#  {'label': 'Other symptoms related to this page',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent',
#    'code': '2.3.4',
#    'id': 'Other symptoms related to this page'}},
#  {'label': 'Report of concern. Behaving strangely, but is quiet and under control',
#   'type': 'Criterion',
#   'properties': {'level': 'Normal',
#    'code': 'LVI',
#    'id': 'Report of concern. Behaving strangely, but is quiet and under control'}},
#  {'label': 'Feeling low and inert (listless)',
#   'type': 'Criterion',
#   'properties': {'level': 'Normal',
#    'code': 'LVI',
#    'id': 'Feeling low and inert (listless)'}},
#  {'label': 'Wants to talk to a doctor or others who can help',
#   'type': 'Criterion',
#   'properties': {'level': 'Normal',
#    'code': 'LVI',
#    'id': 'Wants to talk to a doctor or others who can help'}},
#  {'label': 'Frequent caller without any new problems, known mental health issue',
#   'type': 'Criterion',
#   'properties': {'level': 'Normal',
#    'code': 'LVI',
#    'id': 'Frequent caller without any new problems, known mental health issue'}},
#  {'label': 'Other, not urgent',
#   'type': 'Criterion',
#   'properties': {'level': 'Normal', 'code': 'LVI', 'id': 'Other, not urgent'}},
#  {'label': 'IMPORTANT INFORMATION TO THE CALLER',
#   'type': 'Advice',
#   'properties': {'advice_id': 1, 'id': 'IMPORTANT INFORMATION TO THE CALLER'}},
#  {'label': 'MEDICATION',
#   'type': 'Advice',
#   'properties': {'advice_id': 2, 'id': 'MEDICATION'}},
#  {'label': 'RESTLESS / AGGRESSIVE PERSON',
#   'type': 'Advice',
#   'properties': {'advice_id': 3, 'id': 'RESTLESS / AGGRESSIVE PERSON'}},
#  {'label': 'IF RELEVANT: Free helpline: 116 123',
#   'type': 'Advice',
#   'properties': {'advice_id': 4, 'id': 'IF RELEVANT: Free helpline: 116 123'}},
#  {'label': 'Are there any children / adolescents present?',
#   'type': 'Question',
#   'properties': {'id': 'Are there any children / adolescents present?'}},
#  {'label': 'Are they in need of immediate care or support?',
#   'type': 'Question',
#   'properties': {'id': 'Are they in need of immediate care or support?'}},
#  {'label': 'Are there any animals that need to be looked after?',
#   'type': 'Question',
#   'properties': {'id': 'Are there any animals that need to be looked after?'}},
#  {'label': 'Do you know if the person has a mental health crisis plan?',
#   'type': 'Question',
#   'properties': {'id': 'Do you know if the person has a mental health crisis plan?'}},
#  {'label': 'If so – where is it?',
#   'type': 'Question',
#   'properties': {'id': 'If so – where is it?'}},
#  {'label': 'How does s/he seem now?',
#   'type': 'Question',
#   'properties': {'id': 'How does s/he seem now?'}},
#  {'label': 'How does s/he answer your questions?',
#   'type': 'Question',
#   'properties': {'id': 'How does s/he answer your questions?'}},
#  {'label': 'Do you know what s/he has taken, and when?',
#   'type': 'Question',
#   'properties': {'id': 'Do you know what s/he has taken, and when?'}},
#  {'label': 'When did it start to get worse?',
#   'type': 'Question',
#   'properties': {'id': 'When did it start to get worse?'}},
#  {'label': 'What can have triggered this?',
#   'type': 'Question',
#   'properties': {'id': 'What can have triggered this?'}},
#  {'label': 'Where has s/he been treated?',
#   'type': 'Question',
#   'properties': {'id': 'Where has s/he been treated?'}},
#  {'label': 'When?', 'type': 'Question', 'properties': {'id': 'When?'}},
#  {'label': 'Is s/he being followed up by a primary health care team?',
#   'type': 'Question',
#   'properties': {'id': 'Is s/he being followed up by a primary health care team?'}},
#  {'label': 'When did things start to change?',
#   'type': 'Question',
#   'properties': {'id': 'When did things start to change?'}},
#  {'label': 'How long has s/he (name) been ill?',
#   'type': 'Question',
#   'properties': {'id': 'How long has s/he (name) been ill?'}},
#  {'label': 'How does s/he feel about you calling us (AMK/LVS)?',
#   'type': 'Question',
#   'properties': {'id': 'How does s/he feel about you calling us (AMK/LVS)?'}},
#  {'label': 'Is it ok or not?',
#   'type': 'Question',
#   'properties': {'id': 'Is it ok or not?'}},
#  {'label': 'Who else is present?',
#   'type': 'Question',
#   'properties': {'id': 'Who else is present?'}},
#  {'label': 'Are they safe?',
#   'type': 'Question',
#   'properties': {'id': 'Are they safe?'}},
#  {'label': 'Are there any dangerous items they can get hold of?',
#   'type': 'Question',
#   'properties': {'id': 'Are there any dangerous items they can get hold of?'}},
#  {'label': 'Is anyone else expected to arrive soon (children, other people with similar problems?)',
#   'type': 'Question',
#   'properties': {'id': 'Is anyone else expected to arrive soon (children, other people with similar problems?)'}},
#  {'label': 'How is the person coping?',
#   'type': 'Question',
#   'properties': {'id': 'How is the person coping?'}},
#  {'label': 'Are there any changes in personal care (is there enough food in the fridge, is personal hygiene ok, is the home clean etc.)?',
#   'type': 'Question',
#   'properties': {'id': 'Are there any changes in personal care (is there enough food in the fridge, is personal hygiene ok, is the home clean etc.)?'}},
#  {'label': 'Confused', 'type': 'Symptom', 'properties': {'id': 'Confused'}},
#  {'label': 'Irritable', 'type': 'Symptom', 'properties': {'id': 'Irritable'}},
#  {'label': 'Boisterous',
#   'type': 'Symptom',
#   'properties': {'id': 'Boisterous'}},
#  {'label': 'Verbally threatening',
#   'type': 'Symptom',
#   'properties': {'id': 'Verbally threatening'}},
#  {'label': 'Physical threats',
#   'type': 'Symptom',
#   'properties': {'id': 'Physical threats'}},
#  {'label': 'Attacking objects',
#   'type': 'Symptom',
#   'properties': {'id': 'Attacking objects'}},
#  {'label': 'Increasing anxiety',
#   'type': 'Symptom',
#   'properties': {'id': 'Increasing anxiety'}},
#  {'label': 'Increasing restlessness',
#   'type': 'Symptom',
#   'properties': {'id': 'Increasing restlessness'}},
#  {'label': 'Confusion', 'type': 'Symptom', 'properties': {'id': 'Confusion'}},
#  {'label': 'Visual hallucinations',
#   'type': 'Symptom',
#   'properties': {'id': 'Visual hallucinations'}},
#  {'label': 'Auditory (hearing) hallucinations',
#   'type': 'Symptom',
#   'properties': {'id': 'Auditory (hearing) hallucinations'}},
#  {'label': 'Verbal threats',
#   'type': 'Symptom',
#   'properties': {'id': 'Verbal threats'}},
#  {'label': 'Threat of violence',
#   'type': 'Symptom',
#   'properties': {'id': 'Threat of violence'}},
#  {'label': 'Indifferent (disinterested)',
#   'type': 'Symptom',
#   'properties': {'id': 'Indifferent (disinterested)'}},
#  {'label': 'Major mood swings',
#   'type': 'Symptom',
#   'properties': {'id': 'Major mood swings'}},
#  {'label': 'Psykoser',
#   'type': 'MedicalCondition',
#   'properties': {'id': 'Psykoser'}},
#  {'label': 'Panikkangst',
#   'type': 'MedicalCondition',
#   'properties': {'id': 'Panikkangst'}},
#  {'label': '116 123',
#   'type': 'InformationResource',
#   'properties': {'id': '116 123'}},
#  {'label': 'UKOM sin rapport «Somatisk helse hos pasienter med alvorlig psykisk lidelse»',
#   'type': 'InformationResource',
#   'properties': {'id': 'UKOM sin rapport «Somatisk helse hos pasienter med alvorlig psykisk lidelse»'}},
#  {'label': 'BRØSET violence checklist',
#   'type': 'InformationResource',
#   'properties': {'id': 'BRØSET violence checklist'}},
#  {'label': 'Any medication',
#   'type': 'Medication',
#   'properties': {'id': 'Any medication'}},
#  {'label': '23 Poisoning – not related to alcohol or drugs',
#   'type': 'ProtocolDocument',
#   'properties': {'filename': '23.md',
#    'id': '23 Poisoning – not related to alcohol or drugs'}},
#  {'label': 'Unconscious (unresponsive)',
#   'type': 'Criterion',
#   'properties': {'level': 'Critical',
#    'code': '1.2.9',
#    'id': 'Unconscious (unresponsive)'}},
#  {'label': 'May have ingested a potentially dangerous amount of a toxic substance',
#   'type': 'Criterion',
#   'properties': {'level': 'Critical',
#    'id': 'May have ingested a potentially dangerous amount of a toxic substance'}},
#  {'label': 'May have ingested a potentially dangerous amount of a toxic substance - Is having a seizure (convulsion, fit)',
#   'type': 'Criterion',
#   'properties': {'level': 'Critical',
#    'code': '1.2.3.9.10',
#    'id': 'May have ingested a potentially dangerous amount of a toxic substance - Is having a seizure (convulsion, fit)'}},
#  {'label': 'May have ingested a potentially dangerous amount of a toxic substance - Serious or continuing (persistent, lasting) airway symptoms',
#   'type': 'Criterion',
#   'properties': {'level': 'Critical',
#    'code': '1.2.4.9.10',
#    'id': 'May have ingested a potentially dangerous amount of a toxic substance - Serious or continuing (persistent, lasting) airway symptoms'}},
#  {'label': 'May have ingested a potentially dangerous amount of a toxic substance - Pale, clammy skin (cold sweating)',
#   'type': 'Criterion',
#   'properties': {'level': 'Critical',
#    'code': '1.2.6.9.10',
#    'id': 'May have ingested a potentially dangerous amount of a toxic substance - Pale, clammy skin (cold sweating)'}},
#  {'label': 'May have ingested a potentially dangerous amount of a toxic substance - Difficulty swallowing',
#   'type': 'Criterion',
#   'properties': {'level': 'Critical',
#    'code': '1.2.4.9.10',
#    'id': 'May have ingested a potentially dangerous amount of a toxic substance - Difficulty swallowing'}},
#  {'label': 'May have ingested a potentially dangerous amount of a toxic substance - The situation requires immediate treatment to avoid serious symptoms or injury. Assess the amount taken. In certain cases this could be a YELLOW response (urgent)',
#   'type': 'Criterion',
#   'properties': {'level': 'Critical',
#    'code': '1.2.9.10',
#    'id': 'May have ingested a potentially dangerous amount of a toxic substance - The situation requires immediate treatment to avoid serious symptoms or injury. Assess the amount taken. In certain cases this could be a YELLOW response (urgent)'}},
#  {'label': 'May have ingested a potentially dangerous amount of a toxic substance - Has swallowed a battery, eg. a button battery, has symptoms',
#   'type': 'Criterion',
#   'properties': {'level': 'Critical',
#    'code': '1.2.9.10',
#    'id': 'May have ingested a potentially dangerous amount of a toxic substance - Has swallowed a battery, eg. a button battery, has symptoms'}},
#  {'label': 'May have ingested a potentially dangerous amount of a toxic substance - Has ingested a corrosive substance causing swallowing difficulties E.g. drain unblocker/cleaner, lye, caustic soda, strong acids',
#   'type': 'Criterion',
#   'properties': {'level': 'Critical',
#    'code': '1.2.7.9.10',
#    'id': 'May have ingested a potentially dangerous amount of a toxic substance - Has ingested a corrosive substance causing swallowing difficulties E.g. drain unblocker/cleaner, lye, caustic soda, strong acids'}},
#  {'label': 'May have ingested a potentially dangerous amount of a toxic substance Assess the amount taken. In certain cases this could be a RED response (emergency)',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent',
#    'code': '7.8.9',
#    'id': 'May have ingested a potentially dangerous amount of a toxic substance Assess the amount taken. In certain cases this could be a RED response (emergency)'}},
#  {'label': 'May have ingested a corrosive substance, no airway symptoms, no hoarseness or difficulty swallowing E.g. drain unblocker/cleaner, lye, caustic soda, strong acids',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent',
#    'code': '7.9',
#    'id': 'May have ingested a corrosive substance, no airway symptoms, no hoarseness or difficulty swallowing E.g. drain unblocker/cleaner, lye, caustic soda, strong acids'}},
#  {'label': 'Ingested an oil-based or petroleum product, no cough E.g. lighter fluid, white spirit, lamp oil, paraffin, petrol or diesel',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent',
#    'code': '8.9',
#    'id': 'Ingested an oil-based or petroleum product, no cough E.g. lighter fluid, white spirit, lamp oil, paraffin, petrol or diesel'}},
#  {'label': 'Suspect self inflicted injury or neglect',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent',
#    'code': '2.9',
#    'id': 'Suspect self inflicted injury or neglect'}},
#  {'label': 'Other symptoms related to this page',
#   'type': 'Criterion',
#   'properties': {'level': 'Urgent',
#    'code': '2.9',
#    'id': 'Other symptoms related to this page'}},
#  {'label': 'May have ingested a small amount of a toxic substance, no symptoms',
#   'type': 'Criterion',
#   'properties': {'level': 'Normal',
#    'code': 'LVI',
#    'id': 'May have ingested a small amount of a toxic substance, no symptoms'}},
#  {'label': 'Other, not urgent',
#   'type': 'Criterion',
#   'properties': {'level': 'Normal', 'code': 'LVI', 'id': 'Other, not urgent'}},
#  {'label': 'IMPORTANT INFORMATION TO THE CALLER',
#   'type': 'Advice',
#   'properties': {'advice_id': 1, 'id': 'IMPORTANT INFORMATION TO THE CALLER'}},
#  {'label': 'SAFETY AT THE SCENE',
#   'type': 'Advice',
#   'properties': {'advice_id': 2, 'id': 'SAFETY AT THE SCENE'}},
#  {'label': 'UNRESPONSIVE / CONVULSIONS',
#   'type': 'Advice',
#   'properties': {'advice_id': 3, 'id': 'UNRESPONSIVE / CONVULSIONS'}},
#  {'label': 'DIFFICULTY BREATHING',
#   'type': 'Advice',
#   'properties': {'advice_id': 4, 'id': 'DIFFICULTY BREATHING'}},
#  {'label': 'DIFFICULT TO WAKE, DROWSY, SLEEPY (altered level of consciousness)',
#   'type': 'Advice',
#   'properties': {'advice_id': 5,
#    'id': 'DIFFICULT TO WAKE, DROWSY, SLEEPY (altered level of consciousness)'}},
#  {'label': 'PALE, CLAMMY SKIN',
#   'type': 'Advice',
#   'properties': {'advice_id': 6, 'id': 'PALE, CLAMMY SKIN'}},
#  {'label': 'CORROSIVES IN THE MOUTH / THROAT',
#   'type': 'Advice',
#   'properties': {'advice_id': 7, 'id': 'CORROSIVES IN THE MOUTH / THROAT'}},
#  {'label': 'HAS INGESTED A PETROLEUMBASED PRODUCT',
#   'type': 'Advice',
#   'properties': {'advice_id': 8,
#    'id': 'HAS INGESTED A PETROLEUMBASED PRODUCT'}},
#  {'label': 'KEEP ALL PACKAGING',
#   'type': 'Advice',
#   'properties': {'advice_id': 9, 'id': 'KEEP ALL PACKAGING'}},
#  {'label': 'MEDICATION',
#   'type': 'Advice',
#   'properties': {'advice_id': 10, 'id': 'MEDICATION'}},
#  {'label': 'Are there any children / adolescents present?',
#   'type': 'Question',
#   'properties': {'id': 'Are there any children / adolescents present?'}},
#  {'label': 'Are they in need of immediate care or support?',
#   'type': 'Question',
#   'properties': {'id': 'Are they in need of immediate care or support?'}},
#  {'label': 'What can s/he have been exposed to?',
#   'type': 'Question',
#   'properties': {'id': 'What can s/he have been exposed to?'}},
#  {'label': 'Include the name of the product and the amount taken (strength, solution?).',
#   'type': 'Question',
#   'properties': {'id': 'Include the name of the product and the amount taken (strength, solution?).'}},
#  {'label': 'About the casualty: Age, weight, in good health? Symptoms before the exposure?',
#   'type': 'Question',
#   'properties': {'id': 'About the casualty: Age, weight, in good health? Symptoms before the exposure?'}},
#  {'label': 'Timeline: How long ago did it happen? Do you know how long the exposure time is for this product?',
#   'type': 'Question',
#   'properties': {'id': 'Timeline: How long ago did it happen? Do you know how long the exposure time is for this product?'}},
#  {'label': 'How did it happen (accident, abuse or self-harm)?',
#   'type': 'Question',
#   'properties': {'id': 'How did it happen (accident, abuse or self-harm)?'}},
#  {'label': 'Could s/he have taken anything else?',
#   'type': 'Question',
#   'properties': {'id': 'Could s/he have taken anything else?'}},
#  {'label': 'Could others present have taken the same?',
#   'type': 'Question',
#   'properties': {'id': 'Could others present have taken the same?'}},
#  {'label': 'Is s/he behaving normally?',
#   'type': 'Question',
#   'properties': {'id': 'Is s/he behaving normally?'}},
#  {'label': 'Has s/he vomited?',
#   'type': 'Question',
#   'properties': {'id': 'Has s/he vomited?'}},
#  {'label': 'Is s/he on daily medication? What?',
#   'type': 'Question',
#   'properties': {'id': 'Is s/he on daily medication? What?'}},
#  {'label': 'helsebiblioteket.no/forgiftninger',
#   'type': 'InformationResource',
#   'properties': {'id': 'helsebiblioteket.no/forgiftninger'}},
#  {'label': 'helsebiblioteket.no/giftinformasjon/planter-og-bara-a/planteforgiftninger/#giftige-planter-i-norge',
#   'type': 'InformationResource',
#   'properties': {'id': 'helsebiblioteket.no/giftinformasjon/planter-og-bara-a/planteforgiftninger/#giftige-planter-i-norge'}},
#  {'label': 'helsebiblioteket.no/giftinformasjon/sopp/norgesgiftigste-sopper/',
#   'type': 'InformationResource',
#   'properties': {'id': 'helsebiblioteket.no/giftinformasjon/sopp/norgesgiftigste-sopper/'}},
#  {'label': 'helsebiblioteket.no/giftinformasjon/mat-og-drikke/blaskjell-og-krabbe-forgiftninger/',
#   'type': 'InformationResource',
#   'properties': {'id': 'helsebiblioteket.no/giftinformasjon/mat-og-drikke/blaskjell-og-krabbe-forgiftninger/'}},
#  {'label': 'Voksen over 65 år',
#   'type': 'PatientQualifier',
#   'properties': {'id': 'Voksen over 65 år'}},
#  {'label': 'Barn under 5 år',
#   'type': 'PatientQualifier',
#   'properties': {'id': 'Barn under 5 år'}},
#  {'label': 'Alvorlig grunnsykdom',
#   'type': 'PatientQualifier',
#   'properties': {'id': 'Alvorlig grunnsykdom'}},
#  {'label': 'Ruspåvirkning',
#   'type': 'PatientQualifier',
#   'properties': {'id': 'Ruspåvirkning'}}]

# %%
all_graph_relationships
# Out:
# [{'source_label': '01 Unconscious adult – not breathing normally',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Critical'},
#  {'source_label': 'Critical',
#   'relation_label': 'PRESENTS_SYMPTOM',
#   'target_label': 'Unconscious adult, not breathing normally'},
#  {'source_label': 'Critical',
#   'relation_label': 'SIGNALS_CONDITION',
#   'target_label': 'Heart arrest'},
#  {'source_label': '01 Unconscious adult – not breathing normally',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'Help is on the way as I speak to you.'},
#  {'source_label': '01 Unconscious adult – not breathing normally',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'Start CPR'},
#  {'source_label': 'Start CPR',
#   'relation_label': 'APPLIES_TO_PATIENT_TYPE',
#   'target_label': 'Adult'},
#  {'source_label': 'Start CPR',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Defibrillator',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Hjertestarterregisteret',
#   'relation_label': 'MENTIONS_RESOURCE',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Blocked airway',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Children / adolescents present',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Immediate care or support needed',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Rescuing a pregnant person in the 3rd trimester',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'High voltage electrical exposure',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Drowning',
#   'relation_label': 'DEFINES_SCENARIO',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Overdose',
#   'relation_label': 'DEFINES_SCENARIO',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Hanging',
#   'relation_label': 'DEFINES_SCENARIO',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Cardio Pulmonary Resuscitation (CPR)',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Chest compressions',
#   'relation_label': 'HAS_INSTRUCTION',
#   'target_label': 'Cardio Pulmonary Resuscitation (CPR)'},
#  {'source_label': 'Rescue breaths',
#   'relation_label': 'HAS_INSTRUCTION',
#   'target_label': 'Cardio Pulmonary Resuscitation (CPR)'},
#  {'source_label': 'AED (Automated External Defibrillator)',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'ROSC (Return of Spontaneous Circulation)',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Ischemic heart disease',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Agonal breath',
#   'relation_label': 'PRESENTS_SYMPTOM',
#   'target_label': 'Unconscious adult, not breathing normally'},
#  {'source_label': 'Speakerphone usage',
#   'relation_label': 'HAS_INSTRUCTION',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Metronome for chest compressions',
#   'relation_label': 'USES_DEVICE',
#   'target_label': 'Chest compressions'},
#  {'source_label': 'HLR-instruksjoner',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Sedation and stabilization assistance',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Defibrillation',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Terminally ill patient decision',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Neonatal presence',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': '01 Unconscious adult – not breathing normally',
#   'relation_label': 'CONCERNS_PATIENT_TYPE',
#   'target_label': 'Adult'},
#  {'source_label': '01 Unconscious adult – not breathing normally',
#   'relation_label': 'MENTIONS_RESOURCE',
#   'target_label': 'Hjertestarterregisteret'},
#  {'source_label': '01 Unconscious adult – not breathing normally',
#   'relation_label': 'MENTIONS_RESOURCE',
#   'target_label': 'Se 21 Dødsfall / mulig dødsfall og Legevaktindeks'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Very restless (troubled, agitated). In immediate or imminent danger to self or others'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Aggressive, threatening behaviour. In immediate or imminent danger to self or others'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Increasing anxiety'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Increasing restlessness and/or confusion'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Visual and/or auditory (hearing) hallucinations'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Verbal threats'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Threat of violence'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Indifferent (disinterested) or major mood swings'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Caller needs assistance'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Change in behaviour or mood, does not have a known mental health problem'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Known mental health issue, several calls, probably needs medical assistance'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Other symptoms related to this page'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Report of concern. Behaving strangely, but is quiet and under control'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Feeling low and inert (listless)'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Wants to talk to a doctor or others who can help'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Frequent caller without any new problems, known mental health issue'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Other, not urgent'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'IMPORTANT INFORMATION TO THE CALLER'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'MEDICATION'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'RESTLESS / AGGRESSIVE PERSON'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'IF RELEVANT:'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Are there any children / adolescents present? Are they in need of immediate care or support?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Are there any animals that need to be looked after?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Do you know if the person has a mental health crisis plan? If so – where is it?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'How does s/he seem now? How does s/he answer your questions?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Do you know what s/he has taken, and when?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'When did it start to get worse? What can have triggered this?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Where has s/he been treated? When?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Is s/he being followed up by a primary health care team?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'When did things start to change? What can have triggered this?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'How long has s/he (name) been ill?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'How does s/he feel about you calling us (AMK/LVS)? Is it ok or not?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Who else is present?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Are they safe?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Are there any dangerous items they can get hold of?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Is anyone else expected to arrive soon (children, other people with similar problems?)'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'How is the person coping? Are there any changes in personal care (is there enough food in the fridge, is personal hygiene ok, is the home clean etc.)'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'MENTIONS_RESOURCE',
#   'target_label': 'UKOM report "Somatisk helse hos pasienter med alvorlig psykisk lidelse"'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'MENTIONS_RESOURCE',
#   'target_label': 'SAMTYKKEKOMPETANSE'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'DEFINES_SCENARIO',
#   'target_label': 'Clarify BVC status in the event of aggressive, threatening or violent behaviour.'},
#  {'source_label': 'Clarify BVC status in the event of aggressive, threatening or violent behaviour.',
#   'relation_label': 'LEADS_TO_ACTION',
#   'target_label': 'BRØSET violence checklist'},
#  {'source_label': 'BRØSET violence checklist',
#   'relation_label': 'IS_A_PROCEDURE',
#   'target_label': 'BRØSET violence checklist'},
#  {'source_label': 'BRØSET violence checklist',
#   'relation_label': 'HAS_INSTRUCTION',
#   'target_label': 'No = 0 / Yes = 1'},
#  {'source_label': 'BRØSET violence checklist',
#   'relation_label': 'HAS_INSTRUCTION',
#   'target_label': 'Confused'},
#  {'source_label': 'BRØSET violence checklist',
#   'relation_label': 'HAS_INSTRUCTION',
#   'target_label': 'Irritable'},
#  {'source_label': 'BRØSET violence checklist',
#   'relation_label': 'HAS_INSTRUCTION',
#   'target_label': 'Boisterous'},
#  {'source_label': 'BRØSET violence checklist',
#   'relation_label': 'HAS_INSTRUCTION',
#   'target_label': 'Verbally threatening'},
#  {'source_label': 'BRØSET violence checklist',
#   'relation_label': 'HAS_INSTRUCTION',
#   'target_label': 'Physical threats'},
#  {'source_label': 'BRØSET violence checklist',
#   'relation_label': 'HAS_INSTRUCTION',
#   'target_label': 'Attacking objects'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'Medication must accompany the person'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Critical | Unconscious (unresponsive)'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Critical | May have ingested a potentially dangerous amount of a toxic substance'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Critical | May have ingested a potentially dangerous amount of a toxic substance - Is having a seizure (convulsion, fit)'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Critical | May have ingested a potentially dangerous amount of a toxic substance - Serious or continuing airway symptoms'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Critical | May have ingested a potentially dangerous amount of a toxic substance - Pale, clammy skin (cold sweating)'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Critical | May have ingested a potentially dangerous amount of a toxic substance - Difficulty swallowing'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Critical | May have ingested a potentially dangerous amount of a toxic substance - Immediate treatment required to avoid serious symptoms or injury'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Critical | May have ingested a potentially dangerous amount of a toxic substance - Has swallowed a battery with symptoms'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Critical | May have ingested a corrosive substance causing swallowing difficulties'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Urgent | May have ingested a potentially dangerous amount of a toxic substance (RED response)'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Urgent | May have ingested a corrosive substance without airway symptoms'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Urgent | Ingested an oil-based or petroleum product without cough'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Urgent | Suspect self-inflicted injury or neglect'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Urgent | Other symptoms related to this page'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Normal | May have ingested a small amount of a toxic substance, no symptoms'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Normal | Other, not urgent'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'IMPORTANT INFORMATION TO THE CALLER'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'SAFETY AT THE SCENE'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'UNRESPONSIVE / CONVULSIONS'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'DIFFICULTY BREATHING'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'DIFFICULT TO WAKE, DROWSY, SLEEPY (altered level of consciousness)'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'PALE, CLAMMY SKIN'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'CORROSIVES IN THE MOUTH / THROAT'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'HAS INGESTED A PETROLEUMBASED PRODUCT'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'KEEP ALL PACKAGING'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'MEDICATION'},
#  {'source_label': 'Critical | Unconscious (unresponsive)',
#   'relation_label': 'PRESENTS_SYMPTOM',
#   'target_label': 'Unconscious'},
#  {'source_label': 'Critical | May have ingested a potentially dangerous amount of a toxic substance - Is having a seizure (convulsion, fit)',
#   'relation_label': 'PRESENTS_SYMPTOM',
#   'target_label': 'Seizure (convulsion, fit)'},
#  {'source_label': 'Critical | May have ingested a potentially dangerous amount of a toxic substance - Serious or continuing airway symptoms',
#   'relation_label': 'PRESENTS_SYMPTOM',
#   'target_label': 'Serious or continuing airway symptoms'},
#  {'source_label': 'Critical | May have ingested a potentially dangerous amount of a toxic substance - Pale, clammy skin (cold sweating)',
#   'relation_label': 'PRESENTS_SYMPTOM',
#   'target_label': 'Pale, clammy skin (cold sweating)'},
#  {'source_label': 'Critical | May have ingested a potentially dangerous amount of a toxic substance - Difficulty swallowing',
#   'relation_label': 'PRESENTS_SYMPTOM',
#   'target_label': 'Difficulty swallowing'},
#  {'source_label': 'Critical | May have ingested a potentially dangerous amount of a toxic substance - Immediate treatment required to avoid serious symptoms or injury',
#   'relation_label': 'SIGNALS_CONDITION',
#   'target_label': 'Immediate treatment required'},
#  {'source_label': 'Critical | May have ingested a potentially dangerous amount of a toxic substance - Has swallowed a battery with symptoms',
#   'relation_label': 'SIGNALS_CONDITION',
#   'target_label': 'Swallowed battery'},
#  {'source_label': 'Critical | May have ingested a corrosive substance causing swallowing difficulties',
#   'relation_label': 'SIGNALS_CONDITION',
#   'target_label': 'Ingested corrosive substance causing swallowing difficulties'},
#  {'source_label': 'Critical | May have ingested a potentially dangerous amount of a toxic substance - Has swallowed a battery with symptoms',
#   'relation_label': 'USES_DEVICE',
#   'target_label': 'Corrosives in the mouth/throat'},
#  {'source_label': 'Immediate treatment required',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'Swallowed battery',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'Ingested corrosive substance causing swallowing difficulties',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'Unconscious',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'Seizure (convulsion, fit)',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'Serious or continuing airway symptoms',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'Pale, clammy skin (cold sweating)',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'Difficulty swallowing',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'IMPORTANT INFORMATION TO THE CALLER',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'SAFETY AT THE SCENE',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'UNRESPONSIVE / CONVULSIONS',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'DIFFICULTY BREATHING',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'DIFFICULT TO WAKE, DROWSY, SLEEPY (altered level of consciousness)',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'PALE, CLAMMY SKIN',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'CORROSIVES IN THE MOUTH / THROAT',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'HAS INGESTED A PETROLEUMBASED PRODUCT',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'KEEP ALL PACKAGING',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'MEDICATION',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'Unconscious',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'Seizure (convulsion, fit)',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'Serious or continuing airway symptoms',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'Pale, clammy skin (cold sweating)',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'Difficulty swallowing',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'Immediate treatment required',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'Swallowed battery',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'Ingested corrosive substance causing swallowing difficulties',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'Corrosives in the mouth/throat',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'Petroleum-based product ingestion',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'Medication being used by the person',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': '01 Unconscious adult – not breathing normally',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Critical | Unconscious adult, not breathing normally'},
#  {'source_label': 'Critical | Unconscious adult, not breathing normally',
#   'relation_label': 'TRIGGERS_ADVICE',
#   'target_label': 'Help is on the way as I speak to you.'},
#  {'source_label': 'Critical | Unconscious adult, not breathing normally',
#   'relation_label': 'TRIGGERS_ADVICE',
#   'target_label': 'You must start CPR (reviving the person). I will tell you what to do.'},
#  {'source_label': 'Critical | Unconscious adult, not breathing normally',
#   'relation_label': 'TRIGGERS_ADVICE',
#   'target_label': 'Don’t hang up, put the phone on speaker if you can.'},
#  {'source_label': 'Critical | Unconscious adult, not breathing normally',
#   'relation_label': 'TRIGGERS_ADVICE',
#   'target_label': 'If there is defibrillator at hand, get someone else to fetch it.'},
#  {'source_label': 'Critical | Unconscious adult, not breathing normally',
#   'relation_label': 'TRIGGERS_ADVICE',
#   'target_label': 'Check Hjertestarterregisteret'},
#  {'source_label': 'Critical | Unconscious adult, not breathing normally',
#   'relation_label': 'TRIGGERS_ADVICE',
#   'target_label': 'If you suspect a blocked airway, open the mouth to see if you can remove any object.'},
#  {'source_label': 'Critical | Unconscious adult, not breathing normally',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Are there any children / adolescents present?'},
#  {'source_label': 'Critical | Unconscious adult, not breathing normally',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Are they in need of immediate care or support?'},
#  {'source_label': 'Critical | Unconscious adult, not breathing normally',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'Gi veiledning i sikring av fri luftvei og HLR.'},
#  {'source_label': 'Critical | Unconscious adult, not breathing normally',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'Tilby ALLE innringere veiledning, selv om de kan HLR fra før.'},
#  {'source_label': 'Critical | Unconscious adult, not breathing normally',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'Gi kontinuerlig veiledning og oppmuntring.'},
#  {'source_label': 'Critical | Unconscious adult, not breathing normally',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'HLR-instruksjoner likevel tilbys'},
#  {'source_label': 'Critical | Unconscious adult, not breathing normally',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'Vær respektfull overfor innringer'},
#  {'source_label': 'Critical | Unconscious adult, not breathing normally',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'Legg en pute under høyre hofte / korsryggen på personen'},
#  {'source_label': 'Critical | Unconscious adult, not breathing normally',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'Ikke ta i noen som fortsatt er i kontakt med strømkilde.'},
#  {'source_label': 'Critical | Unconscious adult, not breathing normally',
#   'relation_label': 'MENTIONS_RESOURCE',
#   'target_label': 'Se 21 Dødsfall / mulig dødsfall og Legevaktindeks'},
#  {'source_label': '01 Unconscious adult – not breathing normally',
#   'relation_label': 'DEFINES_SCENARIO',
#   'target_label': 'Overdose, hanging or other reasons related to breathing.'},
#  {'source_label': 'Overdose, hanging or other reasons related to breathing.',
#   'relation_label': 'LEADS_TO_ACTION',
#   'target_label': 'Push down at this rate 30 times.'},
#  {'source_label': 'Overdose, hanging or other reasons related to breathing.',
#   'relation_label': 'LEADS_TO_ACTION',
#   'target_label': 'Give rescue breaths.'},
#  {'source_label': 'Push down at this rate 30 times.',
#   'relation_label': 'IS_A_PROCEDURE',
#   'target_label': 'CARDIO PULMONARY RESUSCITATION'},
#  {'source_label': 'Give rescue breaths.',
#   'relation_label': 'IS_A_PROCEDURE',
#   'target_label': 'CARDIO PULMONARY RESUSCITATION'},
#  {'source_label': 'CARDIO PULMONARY RESUSCITATION',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Start CPR',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Give rescue breaths.',
#   'relation_label': 'USES_DEVICE',
#   'target_label': 'AED'},
#  {'source_label': 'Overdose, hanging or other reasons related to breathing.',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Drowning, overdose, hanging or other reasons related to breathing.',
#   'relation_label': 'DEFINES_SCENARIO',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Is the person drowning?',
#   'relation_label': 'TRIGGERS_ADVICE',
#   'target_label': 'Start giving breaths as quickly as possible, even before the person is out of the water.'},
#  {'source_label': 'Start giving breaths as quickly as possible, even before the person is out of the water.',
#   'relation_label': 'IS_A_PROCEDURE',
#   'target_label': 'CARDIO PULMONARY RESUSCITATION'},
#  {'source_label': 'Chest compressions must be started as soon as it is practically possible.',
#   'relation_label': 'IS_A_PROCEDURE',
#   'target_label': 'CARDIO PULMONARY RESUSCITATION'},
#  {'source_label': 'Is there an AED at hand?',
#   'relation_label': 'TRIGGERS_ADVICE',
#   'target_label': 'If there is a defibrillator at hand, get someone else to fetch it.'},
#  {'source_label': 'If there is a defibrillator at hand, get someone else to fetch it.',
#   'relation_label': 'USES_DEVICE',
#   'target_label': 'Defibrillator'},
#  {'source_label': 'AED',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Defibrillator',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Hjertestarterregisteret',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Legevaktindeks',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'ROSC',
#   'relation_label': 'SIGNALS_CONDITION',
#   'target_label': 'Rozygcirculation restored (ROSC)'},
#  {'source_label': 'Critical | Unconscious adult, not breathing normally',
#   'relation_label': 'SIGNALS_CONDITION',
#   'target_label': 'Rozygcirculation restored (ROSC)'},
#  {'source_label': 'Rozygcirculation restored (ROSC)',
#   'relation_label': 'MAY_BE_TREATED_WITH',
#   'target_label': 'CARDIO PULMONARY RESUSCITATION'},
#  {'source_label': 'Rozygcirculation restored (ROSC)',
#   'relation_label': 'MAY_BE_TREATED_WITH',
#   'target_label': 'Defibrillation'},
#  {'source_label': 'After ROSC',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Ischemic heart disease',
#   'relation_label': 'HAS_SYMPTOM',
#   'target_label': 'Blocked airway'},
#  {'source_label': 'Ischemic heart disease',
#   'relation_label': 'HAS_SYMPTOM',
#   'target_label': 'Agonal breathing'},
#  {'source_label': 'BLOCKED AIRWAY',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Agonal breathing',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Adult',
#   'relation_label': 'CONCERNS_PATIENT_TYPE',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': 'Pregnant in 3rd trimester',
#   'relation_label': 'CONCERNS_PATIENT_TYPE',
#   'target_label': '01 Unconscious adult – not breathing normally'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Very restless (troubled, agitated). In immediate or imminent danger to self or others'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Aggressive, threatening behaviour. In immediate or imminent danger to self or others'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Increasing anxiety'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Increasing restlessness and/or confusion'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Visual and/or auditory (hearing) hallucinations'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Verbal threats'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Threat of violence'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Indifferent (disinterested) or major mood swings'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Caller needs assistance'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Change in behaviour or mood, does not have a known mental health problem'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Known mental health issue, several calls, probably needs medical assistance'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Other symptoms related to this page'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Report of concern. Behaving strangely, but is quiet and under control'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Feeling low and inert (listless)'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Wants to talk to a doctor or others who can help'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Frequent caller without any new problems, known mental health issue'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Other, not urgent'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'IMPORTANT INFORMATION TO THE CALLER'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'MEDICATION'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'RESTLESS / AGGRESSIVE PERSON'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'IF RELEVANT: Free helpline: 116 123'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Are there any children / adolescents present?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Are they in need of immediate care or support?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Are there any animals that need to be looked after?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Do you know if the person has a mental health crisis plan?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'If so – where is it?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'How does s/he seem now?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'How does s/he answer your questions?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Do you know what s/he has taken, and when?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'When did it start to get worse?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'What can have triggered this?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Where has s/he been treated?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'When?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Is s/he being followed up by a primary health care team?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'When did things start to change?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'How long has s/he (name) been ill?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'How does s/he feel about you calling us (AMK/LVS)?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Is it ok or not?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Who else is present?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Are they safe?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Are there any dangerous items they can get hold of?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Is anyone else expected to arrive soon (children, other people with similar problems?)'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'How is the person coping?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Are there any changes in personal care (is there enough food in the fridge, is personal hygiene ok, is the home clean etc.)?'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'MENTIONS_RESOURCE',
#   'target_label': '116 123'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'MENTIONS_RESOURCE',
#   'target_label': 'UKOM sin rapport «Somatisk helse hos pasienter med alvorlig psykisk lidelse»'},
#  {'source_label': '05 Mental health issue',
#   'relation_label': 'MENTIONS_RESOURCE',
#   'target_label': 'BRØSET violence checklist'},
#  {'source_label': 'Any medication',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'IMPORTANT INFORMATION TO THE CALLER',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'MEDICATION',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'RESTLESS / AGGRESSIVE PERSON',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'IF RELEVANT: Free helpline: 116 123',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Are there any children / adolescents present?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Are they in need of immediate care or support?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Are there any animals that need to be looked after?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Do you know if the person has a mental health crisis plan?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'If so – where is it?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'How does s/he seem now?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'How does s/he answer your questions?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Do you know what s/he has taken, and when?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'When did it start to get worse?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'What can have triggered this?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Where has s/he been treated?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'When?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Is s/he being followed up by a primary health care team?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'When did things start to change?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'How long has s/he (name) been ill?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'How does s/he feel about you calling us (AMK/LVS)?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Is it ok or not?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Who else is present?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Are they safe?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Are there any dangerous items they can get hold of?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Is anyone else expected to arrive soon (children, other people with similar problems?)',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'How is the person coping?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Are there any changes in personal care (is there enough food in the fridge, is personal hygiene ok, is the home clean etc.)?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Confused',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Irritable',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Boisterous',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Verbally threatening',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Physical threats',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Attacking objects',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Increasing anxiety',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Increasing restlessness',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Confusion',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Visual hallucinations',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Auditory (hearing) hallucinations',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Verbal threats',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Threat of violence',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Indifferent (disinterested)',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Major mood swings',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Psykoser',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'Panikkangst',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': '116 123',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'UKOM sin rapport «Somatisk helse hos pasienter med alvorlig psykisk lidelse»',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': 'BRØSET violence checklist',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '05 Mental health issue'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Unconscious (unresponsive)'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'May have ingested a potentially dangerous amount of a toxic substance'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'May have ingested a potentially dangerous amount of a toxic substance - Is having a seizure (convulsion, fit)'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'May have ingested a potentially dangerous amount of a toxic substance - Serious or continuing (persistent, lasting) airway symptoms'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'May have ingested a potentially dangerous amount of a toxic substance - Pale, clammy skin (cold sweating)'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'May have ingested a potentially dangerous amount of a toxic substance - Difficulty swallowing'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'May have ingested a potentially dangerous amount of a toxic substance - The situation requires immediate treatment to avoid serious symptoms or injury. Assess the amount taken. In certain cases this could be a YELLOW response (urgent)'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'May have ingested a potentially dangerous amount of a toxic substance - Has swallowed a battery, eg. a button battery, has symptoms'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'May have ingested a potentially dangerous amount of a toxic substance - Has ingested a corrosive substance causing swallowing difficulties E.g. drain unblocker/cleaner, lye, caustic soda, strong acids'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'May have ingested a potentially dangerous amount of a toxic substance Assess the amount taken. In certain cases this could be a RED response (emergency)'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'May have ingested a corrosive substance, no airway symptoms, no hoarseness or difficulty swallowing E.g. drain unblocker/cleaner, lye, caustic soda, strong acids'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Ingested an oil-based or petroleum product, no cough E.g. lighter fluid, white spirit, lamp oil, paraffin, petrol or diesel'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Suspect self inflicted injury or neglect'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Other symptoms related to this page'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'May have ingested a small amount of a toxic substance, no symptoms'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_CRITERION',
#   'target_label': 'Other, not urgent'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'IMPORTANT INFORMATION TO THE CALLER'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'SAFETY AT THE SCENE'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'UNRESPONSIVE / CONVULSIONS'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'DIFFICULTY BREATHING'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'DIFFICULT TO WAKE, DROWSY, SLEEPY (altered level of consciousness)'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'PALE, CLAMMY SKIN'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'CORROSIVES IN THE MOUTH / THROAT'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'HAS INGESTED A PETROLEUMBASED PRODUCT'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'KEEP ALL PACKAGING'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'HAS_ADVICE',
#   'target_label': 'MEDICATION'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Are there any children / adolescents present?'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Are they in need of immediate care or support?'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'What can s/he have been exposed to?'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Include the name of the product and the amount taken (strength, solution?).'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'About the casualty: Age, weight, in good health? Symptoms before the exposure?'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Timeline: How long ago did it happen? Do you know how long the exposure time is for this product?'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'How did it happen (accident, abuse or self-harm)?'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Could s/he have taken anything else?'},
#  {'source_label': '23 Poisoning – not related to alcohol or drugs',
#   'relation_label': 'SUGGESTS_QUESTION',
#   'target_label': 'Could others present have taken the same?'},
#  {'source_label': 'IMPORTANT INFORMATION TO THE CALLER',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'SAFETY AT THE SCENE',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'UNRESPONSIVE / CONVULSIONS',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'DIFFICULTY BREATHING',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'DIFFICULT TO WAKE, DROWSY, SLEEPY (altered level of consciousness)',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'PALE, CLAMMY SKIN',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'CORROSIVES IN THE MOUTH / THROAT',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'HAS INGESTED A PETROLEUMBASED PRODUCT',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'KEEP ALL PACKAGING',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'MEDICATION',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'Are there any children / adolescents present?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'Are they in need of immediate care or support?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'What can s/he have been exposed to?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'Include the name of the product and the amount taken (strength, solution?).',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'About the casualty: Age, weight, in good health? Symptoms before the exposure?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'Timeline: How long ago did it happen? Do you know how long the exposure time is for this product?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'How did it happen (accident, abuse or self-harm)?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'Could s/he have taken anything else?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'Could others present have taken the same?',
#   'relation_label': 'PART_OF_PROTOCOL',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'helsebiblioteket.no/forgiftninger',
#   'relation_label': 'MENTIONS_RESOURCE',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'helsebiblioteket.no/giftinformasjon/planter-og-bara-a/planteforgiftninger/#giftige-planter-i-norge',
#   'relation_label': 'MENTIONS_RESOURCE',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'helsebiblioteket.no/giftinformasjon/sopp/norgesgiftigste-sopper/',
#   'relation_label': 'MENTIONS_RESOURCE',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'helsebiblioteket.no/giftinformasjon/mat-og-drikke/blaskjell-og-krabbe-forgiftninger/',
#   'relation_label': 'MENTIONS_RESOURCE',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'Voksen over 65 år',
#   'relation_label': 'CONCERNS_PATIENT_TYPE',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'Barn under 5 år',
#   'relation_label': 'CONCERNS_PATIENT_TYPE',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'Alvorlig grunnsykdom',
#   'relation_label': 'CONCERNS_PATIENT_TYPE',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'},
#  {'source_label': 'Ruspåvirkning',
#   'relation_label': 'CONCERNS_PATIENT_TYPE',
#   'target_label': '23 Poisoning – not related to alcohol or drugs'}]

# %%
from llama_index.core.graph_stores.types import EntityNode, ChunkNode, Relation

graph_data_nodes = []
for node_info in all_graph_nodes:
    node_properties = node_info.get("properties", {})
    # Ensure 'id' is present, fallback to label if necessary for uniqueness
    node_id_val = node_properties.get("id", node_info["label"]).strip()
    node_properties["id"] = node_id_val # Standardize where ID is stored

    graph_data_nodes.append(
        EntityNode(
            label=node_info["label"], # This will be the node_id in SimplePropertyGraphStore
            properties=node_properties,
            name=node_info["type"],
            
        )
    )

graph_data_relations = []
for rel_info in all_graph_relationships:
    graph_data_relations.append(
        Relation(
            source_id=rel_info["source_label"].strip(), # Must match a GraphNode.label
            target_id=rel_info["target_label"].strip(), # Must match a GraphNode.label
            label=rel_info["relation_label"].strip(), # This is the relation type
            # properties=rel_info.get("properties", {}) # If relations have properties
        )
    )

# %%
graph_store = SimplePropertyGraphStore()
graph_store.upsert_nodes(graph_data_nodes)
graph_store.upsert_relations(graph_data_relations)

print("Nodes and relationships added to SimplePropertyGraphStore.")
# Out:
# Nodes and relationships added to SimplePropertyGraphStore.

# %%
# --- Build the PropertyGraphIndex from the populated store ---
index = PropertyGraphIndex.from_existing(
    property_graph_store=graph_store,
    llm=llm, # For querying later
    # embed_model=None # For querying later
    embed_kg_nodes=False
)
print("PropertyGraphIndex built.")
# Out:
# PropertyGraphIndex built.

# %%
index.property_graph_store.save_networkx_graph(name="./kg_manualv3.html")

# %%
query_engine = index.as_query_engine(
        llm=llm,
        # include_text=False # Set to True if you want source text with nodes
    )
protocol_title_to_query = "01 Unconscious adult – not breathing normally" # Example
response = query_engine.query(f"What are the CRITICAL criteria for the protocol '{protocol_title_to_query}'?")
print("\nQuery Response for Critical Criteria:", response)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[122], line 6
#       1 query_engine = index.as_query_engine(
#       2         llm=llm,
#       3         # include_text=False # Set to True if you want source text with nodes
#       4     )
#       5 protocol_title_to_query = "01 Unconscious adult – not breathing normally" # Example
# ----> 6 response = query_engine.query(f"What are the CRITICAL criteria for the protocol '{protocol_title_to_query}'?")
#       7 print("\nQuery Response for Critical Criteria:", response)
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:322, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     319             _logger.debug(f"Failed to reset active_span_id: {e}")
#     321 try:
# --> 322     result = func(*args, **kwargs)
#     323     if isinstance(result, asyncio.Future):
#     324         # If the result is a Future, wrap it
#     325         new_future = asyncio.ensure_future(result)
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\core\base\base_query_engine.py:52, in BaseQueryEngine.query(self, str_or_query_bundle)
#      50     if isinstance(str_or_query_bundle, str):
#      51         str_or_query_bundle = QueryBundle(str_or_query_bundle)
# ---> 52     query_result = self._query(str_or_query_bundle)
#      53 dispatcher.event(
#      54     QueryEndEvent(query=str_or_query_bundle, response=query_result)
#      55 )
#      56 return query_result
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:322, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     319             _logger.debug(f"Failed to reset active_span_id: {e}")
#     321 try:
# --> 322     result = func(*args, **kwargs)
#     323     if isinstance(result, asyncio.Future):
#     324         # If the result is a Future, wrap it
#     325         new_future = asyncio.ensure_future(result)
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\core\query_engine\retriever_query_engine.py:178, in RetrieverQueryEngine._query(self, query_bundle)
#     174 """Answer a query."""
#     175 with self.callback_manager.event(
#     176     CBEventType.QUERY, payload={EventPayload.QUERY_STR: query_bundle.query_str}
#     177 ) as query_event:
# --> 178     nodes = self.retrieve(query_bundle)
#     179     response = self._response_synthesizer.synthesize(
#     180         query=query_bundle,
#     181         nodes=nodes,
#     182     )
#     183     query_event.on_end(payload={EventPayload.RESPONSE: response})
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\core\query_engine\retriever_query_engine.py:133, in RetrieverQueryEngine.retrieve(self, query_bundle)
#     132 def retrieve(self, query_bundle: QueryBundle) -> List[NodeWithScore]:
# --> 133     nodes = self._retriever.retrieve(query_bundle)
#     134     return self._apply_node_postprocessors(nodes, query_bundle=query_bundle)
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:322, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     319             _logger.debug(f"Failed to reset active_span_id: {e}")
#     321 try:
# --> 322     result = func(*args, **kwargs)
#     323     if isinstance(result, asyncio.Future):
#     324         # If the result is a Future, wrap it
#     325         new_future = asyncio.ensure_future(result)
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\core\base\base_retriever.py:245, in BaseRetriever.retrieve(self, str_or_query_bundle)
#     240 with self.callback_manager.as_trace("query"):
#     241     with self.callback_manager.event(
#     242         CBEventType.RETRIEVE,
#     243         payload={EventPayload.QUERY_STR: query_bundle.query_str},
#     244     ) as retrieve_event:
# --> 245         nodes = self._retrieve(query_bundle)
#     246         nodes = self._handle_recursive_retrieval(query_bundle, nodes)
#     247         retrieve_event.on_end(
#     248             payload={EventPayload.NODES: nodes},
#     249         )
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:322, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     319             _logger.debug(f"Failed to reset active_span_id: {e}")
#     321 try:
# --> 322     result = func(*args, **kwargs)
#     323     if isinstance(result, asyncio.Future):
#     324         # If the result is a Future, wrap it
#     325         new_future = asyncio.ensure_future(result)
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\core\indices\property_graph\retriever.py:52, in PGRetriever._retrieve(self, query_bundle)
#      50 results = []
#      51 if self.use_async:
# ---> 52     return asyncio_run(self._aretrieve(query_bundle))
#      54 for sub_retriever in tqdm(self.sub_retrievers, disable=not self.show_progress):
#      55     results.extend(sub_retriever.retrieve(query_bundle))
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\core\async_utils.py:33, in asyncio_run(coro)
#      30     loop = asyncio.get_event_loop()
#      32     # If we're here, there's an existing loop but it's not running
# ---> 33     return loop.run_until_complete(coro)
#      35 except RuntimeError as e:
#      36     # If we can't get the event loop, we're likely in a different thread, or its already running
#      37     try:
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File C:\Python312\Lib\asyncio\futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File C:\Python312\Lib\asyncio\tasks.py:316, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     314         result = coro.send(None)
#     315     else:
# --> 316         result = coro.throw(exc)
#     317 except StopIteration as exc:
#     318     if self._must_cancel:
#     319         # Task is cancelled right before coro stops.
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\core\indices\property_graph\retriever.py:64, in PGRetriever._aretrieve(self, query_bundle)
#      61 for sub_retriever in self.sub_retrievers:
#      62     tasks.append(sub_retriever.aretrieve(query_bundle))
# ---> 64 async_results = await run_jobs(
#      65     tasks, workers=self.num_workers, show_progress=self.show_progress
#      66 )
#      68 # flatten the results
#      69 return self._deduplicate([node for nodes in async_results for node in nodes])
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:368, in Dispatcher.span.<locals>.async_wrapper(func, instance, args, kwargs)
#     360 self.span_enter(
#     361     id_=id_,
#     362     bound_args=bound_args,
#    (...)    365     tags=tags,
#     366 )
#     367 try:
# --> 368     result = await func(*args, **kwargs)
#     369 except BaseException as e:
#     370     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\core\async_utils.py:148, in run_jobs(jobs, show_progress, workers, desc)
#     146     results = await tqdm_asyncio.gather(*pool_jobs, desc=desc)
#     147 else:
# --> 148     results = await asyncio.gather(*pool_jobs)
#     150 return results
#
# File C:\Python312\Lib\asyncio\tasks.py:385, in Task.__wakeup(self, future)
#     383 def __wakeup(self, future):
#     384     try:
# --> 385         future.result()
#     386     except BaseException as exc:
#     387         # This may also be a cancellation.
#     388         self.__step(exc)
#
# File C:\Python312\Lib\asyncio\tasks.py:314, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     310 try:
#     311     if exc is None:
#     312         # We use the `send` method directly, because coroutines
#     313         # don't have `__iter__` and `__next__` methods.
# --> 314         result = coro.send(None)
#     315     else:
#     316         result = coro.throw(exc)
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:368, in Dispatcher.span.<locals>.async_wrapper(func, instance, args, kwargs)
#     360 self.span_enter(
#     361     id_=id_,
#     362     bound_args=bound_args,
#    (...)    365     tags=tags,
#     366 )
#     367 try:
# --> 368     result = await func(*args, **kwargs)
#     369 except BaseException as e:
#     370     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\core\async_utils.py:139, in run_jobs.<locals>.worker(job)
#     136 @dispatcher.span
#     137 async def worker(job: Coroutine) -> Any:
#     138     async with semaphore:
# --> 139         return await job
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:368, in Dispatcher.span.<locals>.async_wrapper(func, instance, args, kwargs)
#     360 self.span_enter(
#     361     id_=id_,
#     362     bound_args=bound_args,
#    (...)    365     tags=tags,
#     366 )
#     367 try:
# --> 368     result = await func(*args, **kwargs)
#     369 except BaseException as e:
#     370     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\core\base\base_retriever.py:276, in BaseRetriever.aretrieve(self, str_or_query_bundle)
#     271 with self.callback_manager.as_trace("query"):
#     272     with self.callback_manager.event(
#     273         CBEventType.RETRIEVE,
#     274         payload={EventPayload.QUERY_STR: query_bundle.query_str},
#     275     ) as retrieve_event:
# --> 276         nodes = await self._aretrieve(query_bundle=query_bundle)
#     277         nodes = await self._ahandle_recursive_retrieval(
#     278             query_bundle=query_bundle, nodes=nodes
#     279         )
#     280         retrieve_event.on_end(
#     281             payload={EventPayload.NODES: nodes},
#     282         )
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\core\indices\property_graph\sub_retrievers\base.py:148, in BasePGRetriever._aretrieve(self, query_bundle)
#     147 async def _aretrieve(self, query_bundle: QueryBundle) -> List[NodeWithScore]:
# --> 148     nodes = await self.aretrieve_from_graph(query_bundle)
#     149     if self.include_text and nodes:
#     150         nodes = await self.async_add_source_text(nodes)
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:368, in Dispatcher.span.<locals>.async_wrapper(func, instance, args, kwargs)
#     360 self.span_enter(
#     361     id_=id_,
#     362     bound_args=bound_args,
#    (...)    365     tags=tags,
#     366 )
#     367 try:
# --> 368     result = await func(*args, **kwargs)
#     369 except BaseException as e:
#     370     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\core\indices\property_graph\sub_retrievers\llm_synonym.py:139, in LLMSynonymRetriever.aretrieve_from_graph(self, query_bundle, limit)
#     132 response = await self._llm.apredict(
#     133     self._synonym_prompt,
#     134     query_str=query_bundle.query_str,
#     135     max_keywords=self._max_keywords,
#     136 )
#     137 matches = self._parse_llm_output(response)
# --> 139 return await self._aprepare_matches(matches, limit=limit or self._limit)
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\core\indices\property_graph\sub_retrievers\llm_synonym.py:108, in LLMSynonymRetriever._aprepare_matches(self, matches, limit)
#     104 async def _aprepare_matches(
#     105     self, matches: List[str], limit: Optional[int] = None
#     106 ) -> List[NodeWithScore]:
#     107     kg_nodes = await self._graph_store.aget(ids=matches)
# --> 108     triplets = await self._graph_store.aget_rel_map(
#     109         kg_nodes,
#     110         depth=self._path_depth,
#     111         limit=limit or self._limit,
#     112         ignore_rels=[KG_SOURCE_REL],
#     113     )
#     115     return self._get_nodes_with_score(triplets)
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\core\graph_stores\types.py:464, in PropertyGraphStore.aget_rel_map(self, graph_nodes, depth, limit, ignore_rels)
#     456 async def aget_rel_map(
#     457     self,
#     458     graph_nodes: List[LabelledNode],
#    (...)    461     ignore_rels: Optional[List[str]] = None,
#     462 ) -> List[Triplet]:
#     463     """Asynchronously get depth-aware rel map."""
# --> 464     return self.get_rel_map(graph_nodes, depth, limit, ignore_rels)
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\core\graph_stores\simple_labelled.py:112, in SimplePropertyGraphStore.get_rel_map(self, graph_nodes, depth, limit, ignore_rels)
#     109 triplets = []
#     111 cur_depth = 0
# --> 112 graph_triplets = self.get_triplets(ids=[gn.id for gn in graph_nodes])
#     113 seen_triplets = set()
#     115 while len(graph_triplets) > 0 and cur_depth < depth:
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\core\graph_stores\simple_labelled.py:70, in SimplePropertyGraphStore.get_triplets(self, entity_names, relation_names, properties, ids)
#      67 if not ids and not properties and not entity_names and not relation_names:
#      68     return []
# ---> 70 triplets = self.graph.get_triplets()
#      71 if entity_names:
#      72     triplets = [
#      73         t
#      74         for t in triplets
#      75         if t[0].id in entity_names or t[2].id in entity_names
#      76     ]
#
# File c:\Users\newac\OneDrive\Desktop\Master\.venv\Lib\site-packages\llama_index\core\graph_stores\types.py:153, in LabelledPropertyGraph.get_triplets(self)
#     148 def get_triplets(self) -> List[Triplet]:
#     149     """Get all triplets."""
#     150     return [
#     151         (
#     152             self.nodes[subj],
# --> 153             self.relations[
#     154                 self._get_relation_key(obj_id=obj, subj_id=subj, rel_id=rel)
#     155             ],
#     156             self.nodes[obj],
#     157         )
#     158         for subj, rel, obj in self.triplets
#     159     ]
#
# KeyError: '05 Mental health issue_MENTIONS_RESOURCE_UKOM report  Somatisk helse hos pasienter med alvorlig psykisk lidelse '

# %%
CoT_prompt_template = """
-Goal-
Given a text document containing medical protocols or guidelines, identify all entities of the specified medical types and all relationships among the identified entities to build a knowledge graph.

I will be using this data to generate a knowledge graph, detect communities and summarise the communities
SO PLEAE BE AWARE OF THE FUTURE PROSPECTS OF THIS PROJECT.
 
 -Steps-
1.  Identify all entities within the text. For each identified entity, extract the following information:
    *   `entity_name`: Name of the entity, capitalized (e.g., CPR, UNCONSCIOUSNESS, NEWBORN).
    *   `entity_type`: One of the relevant medical types provided below.
    *   `entity_description`: Comprehensive description of the entity's attributes, purpose, or actions as described in the text.
    Format each entity as ("entity"{{tuple_delimiter}}<entity_name>{{tuple_delimiter}}<entity_type>{{tuple_delimiter}}<entity_description>)

2.  From the entities identified in step 1, identify all pairs of (source_entity, target_entity) that are *clearly and directly related* within the context of the provided text.
    For each pair of related entities, extract the following information:
    *   `source_entity`: name of the source entity, as identified in step 1.
    *   `target_entity`: name of the target entity, as identified in step 1.
    *   `relationship_description`: explanation in English describing the nature of the relationship between the source and target entity based *only* on the text (e.g., "is a symptom of", "is used to treat", "is performed on", "is a type of", "is indicated for", "uses", "should be checked in case of").
    *   `relationship_strength`: an integer score between 1 (weakly related) to 10 (very strongly and explicitly related).
    Format each relationship as ("relationship"{{tuple_delimiter}}<source_entity>{{tuple_delimiter}}<target_entity>{{tuple_delimiter}}<relationship_description>{{tuple_delimiter}}<relationship_strength>)

3.  Return the output as a single list containing all identified entities and relationships. Use **{{record_delimiter}}** as the delimiter between each entity or relationship record. The primary language of the provided text is mixed English and Norwegian.

4.  Translate Norwegian descriptions into English for the `entity_description` and `relationship_description` fields *only*. Keep entity names and types consistent (preferably English where obvious equivalents exist, otherwise use the capitalized term from the text).

5.  When finished, output {{completion_delimiter}}.

-Relevant Medical Entity Types-
[Medical Condition, Symptom, Patient Group, Medical Procedure, Medical Device/Tool, Medication/Substance, Anatomical Location, Guideline Section, Organization/Role, Medical Concept]

-Examples-
######################

Example 1 (Based on 01.md/02.md):

entity_types: [Medical Condition, Symptom, Patient Group, Medical Procedure, Medical Device/Tool, Medication/Substance, Anatomical Location, Guideline Section, Organization/Role, Medical Concept]
text:
# 01 Unconscious adult – not breathing normally
## CRITERIA
- Critical | Unconscious adult, not breathing normally
## SITUATIONAL GUIDANCE & IMPORTANT TO ASCERTAIN
- Help is on the way as I speak to you.
- You must start CPR (reviving the person). I will tell you what to do.
- Don’t hang up, put the phone on speaker if you can.
- If there is defibrillator at hand, get someone else to fetch it. Check Hjertestarterregisteret (the caller must not fetch a defibrillator / AED if alone)
## EMERGENCY RESPONSE
### SCENARIO
- BCPR (CARDIO PULMONARY RESUSCITATION)
### IF YES
- Push down at this rate 30 times.
- Now give rescue breaths.
- Tilt the head back with one hand on the forehead.
- Lift the chin up with the other hand.
- Pinch the nose and give 2 gentle rescue breaths.
- Continue with 30 pushes and 2 rescue breaths until medics take over or the person wakes up.
- Lay the person on the floor, on his / her back.
- Kneel beside the person’s chest.
- Place your hands in the middle of his / her chest... Push down hard...
------------------------
output:
("entity"{{tuple_delimiter}}UNCONSCIOUS ADULT{{tuple_delimiter}}Patient Group{{tuple_delimiter}}An adult patient who is unconscious and not breathing normally, requiring critical intervention.){{record_delimiter}}
("entity"{{tuple_delimiter}}NOT BREATHING NORMALLY{{tuple_delimiter}}Symptom{{tuple_delimiter}}A critical symptom indicating lack of normal respiration, often associated with unconsciousness.){{record_delimiter}}
("entity"{{tuple_delimiter}}CPR{{tuple_delimiter}}Medical Procedure{{tuple_delimiter}}Cardiopulmonary Resuscitation, a life-saving procedure involving chest compressions and rescue breaths, instructed by the call handler.){{record_delimiter}}
("entity"{{tuple_delimiter}}CHEST COMPRESSIONS{{tuple_delimiter}}Medical Procedure{{tuple_delimiter}}A component of CPR involving pushing down hard on the center of the chest 30 times.){{record_delimiter}}
("entity"{{tuple_delimiter}}RESCUE BREATHS{{tuple_delimiter}}Medical Procedure{{tuple_delimiter}}A component of CPR involving tilting the head, lifting the chin, pinching the nose, and giving 2 gentle breaths into the mouth.){{record_delimiter}}
("entity"{{tuple_delimiter}}AED{{tuple_delimiter}}Medical Device/Tool{{tuple_delimiter}}Automated External Defibrillator (also referred to as defibrillator or Hjertestarter), a device to be fetched if available and if someone else is present.){{record_delimiter}}
("entity"{{tuple_delimiter}}CALLER{{tuple_delimiter}}Organization/Role{{tuple_delimiter}}The person calling for help who is instructed to perform CPR.){{record_delimiter}}
("entity"{{tuple_delimiter}}MEDICS{{tuple_delimiter}}Organization/Role{{tuple_delimiter}}Emergency medical personnel who are on their way and will take over CPR upon arrival.){{record_delimiter}}
("entity"{{tuple_delimiter}}CRITERIA{{tuple_delimiter}}Guideline Section{{tuple_delimiter}}Section defining the conditions under which this protocol applies, such as an unconscious adult not breathing normally.){{record_delimiter}}
("entity"{{tuple_delimiter}}CHEST{{tuple_delimiter}}Anatomical Location{{tuple_delimiter}}The location on the body (middle of the chest) where chest compressions are applied during CPR.){{record_delimiter}}
("entity"{{tuple_delimiter}}HEAD{{tuple_delimiter}}Anatomical Location{{tuple_delimiter}}Body part manipulated during rescue breaths (tilt the head back).){{record_delimiter}}
("entity"{{tuple_delimiter}}CHIN{{tuple_delimiter}}Anatomical Location{{tuple_delimiter}}Body part manipulated during rescue breaths (lift the chin up).){{record_delimiter}}
("relationship"{{tuple_delimiter}}UNCONSCIOUS ADULT{{tuple_delimiter}}NOT BREATHING NORMALLY{{tuple_delimiter}}Is a defining symptom for this patient group according to the criteria.{{tuple_delimiter}}9){{record_delimiter}}
("relationship"{{tuple_delimiter}}CPR{{tuple_delimiter}}UNCONSCIOUS ADULT{{tuple_delimiter}}Is the required procedure for an unconscious adult not breathing normally.{{tuple_delimiter}}10){{record_delimiter}}
("relationship"{{tuple_delimiter}}CPR{{tuple_delimiter}}CHEST COMPRESSIONS{{tuple_delimiter}}Incorporates chest compressions as a key component (30 pushes).{{tuple_delimiter}}9){{record_delimiter}}
("relationship"{{tuple_delimiter}}CPR{{tuple_delimiter}}RESCUE BREATHS{{tuple_delimiter}}Incorporates rescue breaths as a key component (2 breaths).{{tuple_delimiter}}9){{record_delimiter}}
("relationship"{{tuple_delimiter}}CALLER{{tuple_delimiter}}CPR{{tuple_delimiter}}Is instructed to perform CPR.{{tuple_delimiter}}8){{record_delimiter}}
("relationship"{{tuple_delimiter}}AED{{tuple_delimiter}}CPR{{tuple_delimiter}}Should be fetched and used during CPR if available and feasible.{{tuple_delimiter}}7){{record_delimiter}}
("relationship"{{tuple_delimiter}}CHEST COMPRESSIONS{{tuple_delimiter}}CHEST{{tuple_delimiter}}Are applied to the middle of the chest.{{tuple_delimiter}}9){{record_delimiter}}
("relationship"{{tuple_delimiter}}RESCUE BREATHS{{tuple_delimiter}}HEAD{{tuple_delimiter}}Involves tilting the head back.{{tuple_delimiter}}8){{record_delimiter}}
("relationship"{{tuple_delimiter}}RESCUE BREATHS{{tuple_delimiter}}CHIN{{tuple_delimiter}}Involves lifting the chin up.{{tuple_delimiter}}8){{record_delimiter}}
("relationship"{{tuple_delimiter}}MEDICS{{tuple_delimiter}}CPR{{tuple_delimiter}}Will take over CPR from the caller upon arrival.{{tuple_delimiter}}8)
{{completion_delimiter}}
#############################

Example 2 (Based on 20.md):

entity_types: [Medical Condition, Symptom, Patient Group, Medical Procedure, Medical Device/Tool, Medication/Substance, Anatomical Location, Guideline Section, Organization/Role, Medical Concept]
text:
# 20 Diabetes
## CRITERIA
- Critical | Drowsy (decreased level of consciousness) - May have a low blood sugar (hypo) | 1.2.3.5.6
## ADVICE
### Advice 5. IF THE PERSON HAS A HYPO
If necessary and the person has a glucagon injection or nasal spray:
– Give one dose (1 mg) Glucagon...
### Advice 7. DROWSY OR DAZED AND UNABLE TO DRINK
– Do not force the person to drink...
– Alternatively, you can put one or two spoonfuls of honey in the mouth. You can also spread honey or granulated sugar on the gums, between the lips and the teeth.
### Advice 8. THE PERSON IS AWAKE ENOUGH TO DRINK
– Give the person several glasses of sugary drink e.g. fizzy drink, cordial, juice or milk.
## INFORMATION
### HYPOGLYKEMI – LAVT BLODSUKKER
Når blodsukkeret synker under 4 mmol/l... Hvis blodsukkeret faller ytterligere under 3 mmol/l, opptrer føling (insulinføling)... Pas. kan hurtig bli sløv, bevisstløs eller få kramper. Behandlingen er rask tilførsel av sukker eller Glukagon®
------------------------
output:
("entity"{{tuple_delimiter}}DIABETES{{tuple_delimiter}}Medical Condition{{tuple_delimiter}}The underlying medical condition being addressed in this protocol.){{record_delimiter}}
("entity"{{tuple_delimiter}}HYPOGLYCEMIA{{tuple_delimiter}}Medical Condition{{tuple_delimiter}}Low blood sugar (føling/insulinføling), defined as blood sugar below 4 mmol/L or 3 mmol/L, potentially causing drowsiness, unconsciousness, or seizures. Referred to as 'hypo'.){{record_delimiter}}
("entity"{{tuple_delimiter}}DROWSINESS{{tuple_delimiter}}Symptom{{tuple_delimiter}}Decreased level of consciousness, listed as a critical criterion possibly indicating hypoglycemia.){{record_delimiter}}
("entity"{{tuple_delimiter}}GLUCAGON{{tuple_delimiter}}Medication/Substance{{tuple_delimiter}}A medication administered via injection (1mg or 0.5mg dose) or nasal spray (3mg) to treat severe hypoglycemia if available.){{record_delimiter}}
("entity"{{tuple_delimiter}}GLUCAGON KIT{{tuple_delimiter}}Medical Device/Tool{{tuple_delimiter}}Refers to the glucagon injection or nasal spray kit the person might have.){{record_delimiter}}
("entity"{{tuple_delimiter}}HONEY{{tuple_delimiter}}Medication/Substance{{tuple_delimiter}}A sugary substance that can be placed in the mouth or on the gums of a drowsy person unable to drink.){{record_delimiter}}
("entity"{{tuple_delimiter}}GRANULATED SUGAR{{tuple_delimiter}}Medication/Substance{{tuple_delimiter}}A sugary substance that can be spread on the gums of a drowsy person unable to drink.){{record_delimiter}}
("entity"{{tuple_delimiter}}SUGARY DRINK{{tuple_delimiter}}Medication/Substance{{tuple_delimiter}}Drinks like fizzy drinks, cordial, juice, or milk given to a person awake enough to drink to raise blood sugar.){{record_delimiter}}
("entity"{{tuple_delimiter}}GUMS{{tuple_delimiter}}Anatomical Location{{tuple_delimiter}}Location in the mouth where honey or granulated sugar can be applied for absorption in a drowsy patient.){{record_delimiter}}
("entity"{{tuple_delimiter}}ADVICE{{tuple_delimiter}}Guideline Section{{tuple_delimiter}}Section providing instructions on how to manage specific situations like hypoglycemia.){{record_delimiter}}
("entity"{{tuple_delimiter}}INFORMATION{{tuple_delimiter}}Guideline Section{{tuple_delimiter}}Section providing background information on conditions like hypoglycemia.){{record_delimiter}}
("relationship"{{tuple_delimiter}}HYPOGLYCEMIA{{tuple_delimiter}}DIABETES{{tuple_delimiter}}Is a potential complication or state related to Diabetes.{{tuple_delimiter}}9){{record_delimiter}}
("relationship"{{tuple_delimiter}}DROWSINESS{{tuple_delimiter}}HYPOGLYCEMIA{{tuple_delimiter}}Is listed as a potential symptom or consequence of Hypoglycemia.{{tuple_delimiter}}8){{record_delimiter}}
("relationship"{{tuple_delimiter}}GLUCAGON{{tuple_delimiter}}HYPOGLYCEMIA{{tuple_delimiter}}Is a treatment for severe Hypoglycemia.{{tuple_delimiter}}10){{record_delimiter}}
("relationship"{{tuple_delimiter}}HONEY{{tuple_delimiter}}HYPOGLYCEMIA{{tuple_delimiter}}Is an alternative treatment for Hypoglycemia in drowsy patients unable to drink.{{tuple_delimiter}}7){{record_delimiter}}
("relationship"{{tuple_delimiter}}GRANULATED SUGAR{{tuple_delimiter}}HYPOGLYCEMIA{{tuple_delimiter}}Is an alternative treatment for Hypoglycemia in drowsy patients unable to drink.{{tuple_delimiter}}7){{record_delimiter}}
("relationship"{{tuple_delimiter}}SUGARY DRINK{{tuple_delimiter}}HYPOGLYCEMIA{{tuple_delimiter}}Is a treatment for Hypoglycemia in patients awake enough to drink.{{tuple_delimiter}}8){{record_delimiter}}
("relationship"{{tuple_delimiter}}GLUCAGON KIT{{tuple_delimiter}}GLUCAGON{{tuple_delimiter}}Is the delivery method for Glucagon medication.{{tuple_delimiter}}9){{record_delimiter}}
("relationship"{{tuple_delimiter}}HONEY{{tuple_delimiter}}GUMS{{tuple_delimiter}}Can be applied to the gums for absorption.{{tuple_delimiter}}7){{record_delimiter}}
("relationship"{{tuple_delimiter}}GRANULATED SUGAR{{tuple_delimiter}}GUMS{{tuple_delimiter}}Can be applied to the gums for absorption.{{tuple_delimiter}}7)
{{completion_delimiter}}
#############################

-Real Data-
######################
entity_types: [Medical Condition, Symptom, Patient Group, Medical Procedure, Medical Device/Tool, Medication/Substance, Anatomical Location, Guideline Section, Organization/Role, Medical Concept]
text: {input_text}
######################
output:
"""

# %%
cot_prompt = """ 
---Goal---
Given an emergency medical document or call transcript, identify all key entities and relationships that are critical for emergency response coordination and decision-making.
Use English as output language.

---Steps---

1. Identify all entities related to emergency medical response. For each identified entity, extract the following information:

entity_name: Name of the entity, use same language as input text. If English, capitalize the name.

entity_type: One of the following types: [medical_condition, symptom, treatment, procedure, emergency_protocol, response_category, patient_characteristic, location, equipment, severity_level, medication, vital_sign, time_factor, healthcare_professional, communication_method]

entity_description: Comprehensive description of the entity including its characteristics, significance in emergency responses, and potential impact on patient care.

Format each entity as ("entity"|<entity_name>|<entity_type>|<entity_description>)

2. From the entities identified in step 1, identify all pairs of (source_entity, target_entity) that are clearly related to each other in an emergency response context.
For each pair of related entities, extract the following information:

source_entity: name of the source entity, as identified in step 1

target_entity: name of the target entity, as identified in step 1

relationship_description: explanation of how these entities are connected in emergency response contexts and why this relationship is important for effective care

relationship_strength: a numeric score (1-10) indicating how critical this relationship is for emergency responders to understand

relationship_keywords: key words that summarize the nature of the relationship, focusing on emergency medicine concepts or protocols

Format each relationship as ("relationship"|<source_entity>|<target_entity>|<relationship_description>|<relationship_keywords>|<relationship_strength>)

3. Identify high-level emergency response concepts, themes, or topics from the entire text. These should capture the overarching emergency protocols, critical decision points, or priority assessment frameworks present in the document.
Format the content-level key words as ("content_keywords"|<high_level_keywords>)

Return output in English as a single list of all the entities and relationships identified in steps 1 and 2. Use ; as the list delimiter.

When finished, output ###END###

---Example---

Entity_types: [medical_condition, symptom, treatment, procedure, emergency_protocol, response_category, patient_characteristic, location, equipment, severity_level, medication, vital_sign, time_factor, healthcare_professional, communication_method]

Text:
Unconscious adult – not breathing normally
CRITERIA
- Critical | Unconscious adult, not breathing normally
SITUATIONAL GUIDANCE & IMPORTANT TO ASCERTAIN
- Help is on the way as I speak to you.
- You must start CPR (reviving the person). I will tell you what to do.
- Don't hang up, put the phone on speaker if you can.
- If there is defibrillator at hand, get someone else to fetch it.
- If you suspect a blocked airway, open the mouth to see if you can remove any object.
SCENARIO - AM I (RESCUER) TRAINED IN CPR?
IF YES
- Push down at this rate 30 times.
- Now give rescue breaths.
- Tilt the head back with one hand on the forehead.
- Lift the chin up with the other hand.
- Pinch the nose and give 2 gentle rescue breaths.
- Continue with 30 pushes and 2 rescue breaths until medics take over or the person wakes up.

Output:
### start ###
("entity"|"Unconscious Adult"|"patient_characteristic"|"An adult patient who is unresponsive to stimuli, representing a critical emergency situation requiring immediate intervention.");
("entity"|"Not Breathing Normally"|"symptom"|"Abnormal or absent respiratory pattern in a patient, a life-threatening condition requiring immediate resuscitation efforts.");
("entity"|"CPR"|"procedure"|"Cardiopulmonary resuscitation, a lifesaving technique involving chest compressions and rescue breaths for someone who is unconscious and not breathing normally.");
("entity"|"Defibrillator"|"equipment"|"A device that delivers an electric shock to restore normal heart rhythm in someone experiencing cardiac arrest, significantly improving survival chances when used early.");
("entity"|"Blocked Airway"|"medical_condition"|"Obstruction of the respiratory tract that prevents normal breathing, requiring immediate intervention to prevent asphyxiation.");
("entity"|"30 Compressions"|"emergency_protocol"|"Standard CPR protocol requiring 30 chest compressions delivered at the proper rate and depth before rescue breaths are given.");
("entity"|"2 Rescue Breaths"|"emergency_protocol"|"Ventilation procedure in CPR where two breaths are given after 30 compressions, ensuring oxygen delivery to the patient's lungs.");
("entity"|"Head Tilt-Chin Lift"|"procedure"|"Airway management technique where the head is tilted backward and the chin lifted forward to open the airway before giving rescue breaths.");
("entity"|"Critical Response"|"response_category"|"Highest priority emergency response for life-threatening situations requiring immediate medical intervention.");
("relationship"|"Unconscious Adult"|"Not Breathing Normally"|"These conditions typically occur together in cardiac arrest situations and trigger the need for immediate CPR."|"cardiac arrest, resuscitation trigger, life-threatening"|10);
("relationship"|"CPR"|"30 Compressions"|"CPR protocol specifies delivering 30 chest compressions as the first stage of the resuscitation cycle."|"resuscitation protocol, compression cycle, cardiac support"|9);
("relationship"|"CPR"|"2 Rescue Breaths"|"After chest compressions, CPR requires delivering 2 rescue breaths to provide oxygen to the patient."|"ventilation protocol, oxygenation, airway management"|8);
("relationship"|"Head Tilt-Chin Lift"|"2 Rescue Breaths"|"The head tilt-chin lift maneuver must be performed before rescue breaths to ensure an open airway for effective ventilation."|"airway management, ventilation preparation, respiration support"|9);
("relationship"|"Unconscious Adult"|"Critical Response"|"An unconscious adult not breathing normally represents a critical emergency requiring the highest priority response."|"triage priority, emergency classification, response urgency"|10);
("relationship"|"Blocked Airway"|"CPR"|"A blocked airway must be addressed before or during CPR to ensure effectiveness of resuscitation efforts."|"airway clearance, resuscitation prerequisite, ventilation requirement"|9);
("relationship"|"Defibrillator"|"CPR"|"When available, a defibrillator should be used in conjunction with CPR to increase survival chances in cardiac arrest."|"advanced life support, cardiac intervention, survival improvement"|10);
("content_keywords"|"cardiac arrest response, CPR protocol, critical life support, airway management, emergency responder guidance, resuscitation techniques")
###END###

---Real Data---
Entity_types: [medical_condition, symptom, treatment, procedure, emergency_protocol, response_category, patient_characteristic, location, equipment, severity_level, medication, vital_sign, time_factor, healthcare_professional, communication_method]
Text:
{input_text}"""

# %%
#### testinf with just calling llm
response = llm2.chat([ChatMessage(role=MessageRole.USER, content=cot_prompt.format(input_text=documents[0].text))])
# print(response[0])

# %%
def parse_custom_llm_response_to_graph_data(response_text: str):
    """
    Parses a custom LLM response format into entities and relationships.

    Expected format per line:
    ("entity"|"name"|"type"|"description");
    ("relationship"|"source"|"target"|"description"|"keywords_str"|strength);
    ("content_keywords"|"keywords_str");

    Args:
        response_text: The string response from the LLM.

    Returns:
        A dictionary with 'entities', 'relationships', and 'content_keywords'.
        Example:
        {
            'entities': [{'name': '...', 'type': '...', 'description': '...'}, ...],
            'relationships': [{'source': '...', 'target': '...', 'description': '...', 'keywords': '...', 'strength': 0}, ...],
            'content_keywords': "keyword1, keyword2"
        }
    """
    entities = []
    relationships = []
    content_keywords_str = None

    # 1. Clean up the overall string: remove start/end markers and strip whitespace
    if "### start ###" in response_text:
        response_text = response_text.split("### start ###", 1)[1]
    if "###END###" in response_text: # Case sensitive as in your example
        response_text = response_text.split("###END###", 1)[0]
    
    response_text = response_text.strip()
    lines = response_text.splitlines()

    # Regex to extract all quoted values from a line
    # e.g., from ("entity"|"Unconscious Adult"|"patient_characteristic"|"description");
    # it will extract "entity", "Unconscious Adult", "patient_characteristic", "description"
    value_extractor_regex = r'"(.*?)"' # Non-greedy match inside quotes

    for line in lines:
        line = line.strip()
        if not line:
            continue

        # Remove the surrounding ("...") and trailing semicolon if present
        # This makes extracting values simpler
        if line.startswith('(') and line.endswith(');'):
            core_content = line[1:-2] # Remove (" and );
        else:
            print(f"Warning: Skipping malformed line (no parens/semicolon): {line}")
            continue
            
        # Extract all quoted values first
        all_quoted_values = re.findall(value_extractor_regex, core_content)
        
        if not all_quoted_values:
            print(f"Warning: Skipping line with no quoted values: {line}")
            continue

        record_type = all_quoted_values[0] # "entity", "relationship", or "content_keywords"

        try:
            if record_type == "entity":
                if len(all_quoted_values) >= 4:
                    entity = {
                        'name': all_quoted_values[1],
                        'type': all_quoted_values[2],
                        'description': all_quoted_values[3]
                    }
                    entities.append(entity)
                else:
                    print(f"Warning: Malformed entity line (not enough values): {line}")
            
            elif record_type == "relationship":
                # For relationships, the last part (strength) is not quoted.
                # So we need to split the core_content differently.
                # Example: "Unconscious Adult"|"Not Breathing Normally"|"description"|"keywords"|10
                
                # We'll use the quoted values for the text parts, and then find the strength.
                if len(all_quoted_values) >= 5: # "relationship", source, target, desc, keywords
                    # The strength is the last part, after the last quote and pipe
                    parts = core_content.split('|')
                    strength_str = parts[-1].strip() # Get the part after the last pipe
                    
                    relationship = {
                        'source': all_quoted_values[1],
                        'target': all_quoted_values[2],
                        'description': all_quoted_values[3], # This is the relationship's label
                        'keywords': all_quoted_values[4],    # Store as string, can be split later if needed
                        'strength': int(strength_str)
                    }
                    relationships.append(relationship)
                else:
                    print(f"Warning: Malformed relationship line (not enough quoted values): {line}")

            elif record_type == "content_keywords":
                if len(all_quoted_values) >= 2:
                    content_keywords_str = all_quoted_values[1]
                else:
                    print(f"Warning: Malformed content_keywords line: {line}")
            # else:
            #     print(f"Warning: Unknown record type '{record_type}' in line: {line}")

        except IndexError:
            print(f"Warning: Malformed line (IndexError processing values): {line}")
        except ValueError:
            print(f"Warning: Could not convert strength to int in relationship line: {line}")
        except Exception as e:
            print(f"Warning: Unexpected error parsing line '{line}': {e}")

    return {
        "entities": entities,
        "relationships": relationships,
        "content_keywords": content_keywords_str
    }

# %%
parsed_data = parse_custom_llm_response_to_graph_data(response.message.content)

# Print entities and relationships
print(f"Found {len(parsed_data['entities'])} entities and {len(parsed_data['relationships'])} relationships.")
print(f"Content Keywords: {parsed_data['content_keywords']}")

# Example: Access first entity
if parsed_data['entities']:
    print(f"\nFirst entity: {parsed_data['entities'][0]}")

# Example: Access first relationship
if parsed_data['relationships']:
    print(f"\nFirst relationship: {parsed_data['relationships'][0]}")

# Example: Access last entity
if parsed_data['entities']:
    print(f"\nLast entity: {parsed_data['entities'][-1]}")

# Example: Access last relationship
if parsed_data['relationships']:
    print(f"\nLast relationship: {parsed_data['relationships'][-1]}")

print("\n--- All Entities ---")
for i, entity in enumerate(parsed_data['entities']):
    print(f"{i+1}. {entity}")

print("\n--- All Relationships ---")
for i, rel in enumerate(parsed_data['relationships']):
    print(f"{i+1}. {rel}")
# Out:
# Warning: Skipping malformed line (no parens/semicolon): ("content_keywords"|"cardiac arrest response, CPR protocol, airway management, drowning response, emergency response coordination, early defibrillation, resuscitation effectiveness")
# Found 15 entities and 9 relationships.
# Content Keywords: None
#
# First entity: {'name': 'Unconscious Adult', 'type': 'patient_characteristic', 'description': 'An adult patient who is unresponsive to stimuli, indicating a critical emergency requiring immediate intervention and rapid resuscitation efforts.'}
#
# First relationship: {'source': 'Unconscious Adult', 'target': 'Not Breathing Normally', 'description': 'These two conditions frequently occur together in cardiac arrest situations, initiating the need for immediate CPR.', 'keywords': 'cardiac arrest, resuscitation trigger, critical condition', 'strength': 10}
#
# Last entity: {'name': 'Emergency Medical Response', 'type': 'response_category', 'description': 'A systematic approach involving various protocols and actions in response to life-threatening emergency situations.'}
#
# Last relationship: {'source': 'ROSC', 'target': 'Emergency Medical Response', 'description': 'Following successful resuscitation efforts leading to ROSC, rapid transport to a hospital is crucial for further treatment.', 'keywords': 'post-resuscitation care, critical response, transport urgency', 'strength': 10}
#
# --- All Entities ---
# 1. {'name': 'Unconscious Adult', 'type': 'patient_characteristic', 'description': 'An adult patient who is unresponsive to stimuli, indicating a critical emergency requiring immediate intervention and rapid resuscitation efforts.'}
# 2. {'name': 'Not Breathing Normally', 'type': 'symptom', 'description': 'An abnormal respiratory pattern in a patient that may signify cardiac arrest, necessitating immediate actions like CPR for survival.'}
# 3. {'name': 'CPR', 'type': 'procedure', 'description': 'Cardiopulmonary resuscitation, a lifesaving procedure involving chest compressions and rescue breaths for someone who is unconscious and not breathing.'}
# 4. {'name': 'Defibrillator', 'type': 'equipment', 'description': 'A device that delivers an electric shock to restore normal heart rhythm, significantly increasing survival chances in patients experiencing cardiac arrest when used promptly.'}
# 5. {'name': 'Blocked Airway', 'type': 'medical_condition', 'description': 'An obstruction in the respiratory tract preventing airflow, which requires immediate intervention to ensure effective resuscitation and oxygenation.'}
# 6. {'name': '30 Compressions', 'type': 'emergency_protocol', 'description': 'A standard CPR protocol that requires delivering 30 chest compressions before rescue breaths, a critical step in the resuscitation process.'}
# 7. {'name': '2 Rescue Breaths', 'type': 'emergency_protocol', 'description': "A ventilation procedure in CPR involving giving two breaths after every 30 compressions to help provide oxygen to the patient's lungs."}
# 8. {'name': 'Head Tilt-Chin Lift', 'type': 'procedure', 'description': 'An airway management technique used to open the airway by tilting the head backward and lifting the chin, essential before giving rescue breaths.'}
# 9. {'name': 'Drowning', 'type': 'medical_condition', 'description': 'A condition where a patient is submerged in water and unable to breathe, necessitating immediate rescue efforts like CPR and ventilation.'}
# 10. {'name': 'Early Warning', 'type': 'emergency_protocol', 'description': 'Recognizing severe situations quickly and notifying emergency services, which is crucial for timely intervention in life-threatening scenarios.'}
# 11. {'name': 'Early CPR', 'type': 'emergency_protocol', 'description': 'The prompt initiation of cardiopulmonary resuscitation immediately following cardiac arrest, crucial for increasing the chances of survival.'}
# 12. {'name': 'ROSC', 'type': 'medical_condition', 'description': 'Return of Spontaneous Circulation, a critical phase following resuscitation efforts where the heart begins to beat effectively again.'}
# 13. {'name': 'How to Give Good Compressions', 'type': 'procedure', 'description': 'Guidelines to perform effective chest compressions, including techniques to ensure depth and rate for maximizing blood flow during CPR.'}
# 14. {'name': 'High Voltage Electricity Exposure', 'type': 'medical_condition', 'description': "A condition where a patient has been exposed to an electrical source, requiring precautions to ensure the rescuer's safety before assisting the patient."}
# 15. {'name': 'Emergency Medical Response', 'type': 'response_category', 'description': 'A systematic approach involving various protocols and actions in response to life-threatening emergency situations.'}
#
# --- All Relationships ---
# 1. {'source': 'Unconscious Adult', 'target': 'Not Breathing Normally', 'description': 'These two conditions frequently occur together in cardiac arrest situations, initiating the need for immediate CPR.', 'keywords': 'cardiac arrest, resuscitation trigger, critical condition', 'strength': 10}
# 2. {'source': 'CPR', 'target': '30 Compressions', 'description': 'CPR involves performing 30 chest compressions first, a crucial step in the resuscitation cycle.', 'keywords': 'resuscitation protocol, compression cycle, immediate action', 'strength': 9}
# 3. {'source': 'CPR', 'target': '2 Rescue Breaths', 'description': 'CPR protocol requires delivering 2 rescue breaths after 30 compressions to ensure oxygenation of the lungs.', 'keywords': 'ventilation protocol, oxygenation, effective resuscitation', 'strength': 8}
# 4. {'source': 'Head Tilt-Chin Lift', 'target': '2 Rescue Breaths', 'description': 'This maneuver is essential to open the airway prior to providing rescue breaths, ensuring effective ventilation.', 'keywords': 'airway management, effective breathing, CPR procedure', 'strength': 9}
# 5. {'source': 'Blocked Airway', 'target': 'CPR', 'description': 'A blocked airway must be addressed during CPR to optimize the effectiveness of resuscitation efforts.', 'keywords': 'airway obstruction, resuscitation prerequisite, emergency intervention', 'strength': 9}
# 6. {'source': 'Drowning', 'target': 'Early CPR', 'description': 'In drowning cases, early CPR is vital, as prompt action can significantly improve survival chances.', 'keywords': 'emergency protocol, drowning response, immediate action', 'strength': 10}
# 7. {'source': 'Defibrillator', 'target': 'CPR', 'description': 'The use of a defibrillator alongside CPR during a cardiac arrest can dramatically increase the chance of survival.', 'keywords': 'lifesaving equipment, advanced resuscitation, emergency aid', 'strength': 10}
# 8. {'source': 'Early Warning', 'target': 'Emergency Medical Response', 'description': 'Recognizing the severity of a situation and making an emergency call is critical for initiating an effective response.', 'keywords': 'emergency call, recognition, timely response', 'strength': 9}
# 9. {'source': 'ROSC', 'target': 'Emergency Medical Response', 'description': 'Following successful resuscitation efforts leading to ROSC, rapid transport to a hospital is crucial for further treatment.', 'keywords': 'post-resuscitation care, critical response, transport urgency', 'strength': 10}

# %%
def parse_cot_response(response_str: str):
    """
    Parse the Chain-of-Thought structured output into entities and relationships
    for knowledge graph construction.
    
    Args:
        response_str: The raw output string from the LLM
        
    Returns:
        dict: Contains 'entities' and 'relationships' lists
    """
    # Extract just the text content from the ChatResponse object
    if hasattr(response_str, 'message'):
        response_str = response_str.message.content
    
    # Replace placeholder delimiters with actual delimiters for parsing
    response_str = response_str.replace("{tuple_delimiter}", "|||")
    response_str = response_str.replace("{record_delimiter}", "~~~")
    response_str = response_str.replace("{completion_delimiter}", "")
    
    # Split the response into records
    records = response_str.split("~~~")
    
    entities = []
    relationships = []
    
    for record in records:
        record = record.strip()
        if not record:
            continue
            
        # Clean up the record format
        record = record.strip('()"')
        
        # Split the record into its components
        parts = record.split("|||")
        if len(parts) < 3:
            continue
            
        record_type = parts[0].strip('"')
        
        if record_type == "entity":
            if len(parts) >= 4:
                entity = {
                    "name": parts[1].strip(),
                    "type": parts[2].strip(),
                    "description": parts[3].strip()
                }
                entities.append(entity)
                
        elif record_type == "relationship":
            if len(parts) >= 5:
                # Clean and extract just the numerical part for strength
                strength_str = parts[4].strip()
                # Extract only digits from the strength string
                import re
                strength_match = re.search(r'\d+', strength_str)
                strength = int(strength_match.group()) if strength_match else 5  # Default to 5 if no number found
                
                relationship = {
                    "source": parts[1].strip(),
                    "target": parts[2].strip(),
                    "description": parts[3].strip(),
                    "strength": strength
                }
                relationships.append(relationship)
            elif len(parts) >= 4:  # Handle case without strength
                relationship = {
                    "source": parts[1].strip(),
                    "target": parts[2].strip(),
                    "description": parts[3].strip()
                }
                relationships.append(relationship)
    
    return {"entities": entities, "relationships": relationships}

# %%
# Example usage
response_data = parse_cot_response(response)

# Print entities and relationships
print(f"Found {len(response_data['entities'])} entities and {len(response_data['relationships'])} relationships")

# Example: Access first entity
if response_data['entities']:
    print(f"First entity: {response_data['entities'][0]}")

# Example: Access first relationship
if response_data['relationships']:
    print(f"First relationship: {response_data['relationships'][10]}")
# Out:
# Found 12 entities and 13 relationships
# First entity: {'name': 'NOT BREATHING NORMALLY', 'type': 'Symptom', 'description': 'A critical symptom indicating lack of normal respiration, often associated with unconsciousness.'}
# First relationship: {'source': 'DROWNING', 'target': 'NOT BREATHING NORMALLY', 'description': 'Is a potential cause leading to abnormal respiratory patterns and unconsciousness.', 'strength': 8}

# %%
# --- 2. Convert your data to PropertyGraphNode and PropertyGraphRelationship objects ---
from llama_index.core.graph_stores.types import EntityNode, ChunkNode, Relation

pg_nodes = []
for entity_dict in response_data['entities']:
    # Ensure all properties are strings or basic types Pydantic can handle
    # The 'name' becomes id_, 'type' becomes label, rest go into properties
    properties = {k: v for k, v in entity_dict.items() if k not in ['name', 'type']}

    node = EntityNode(
        name=entity_dict['name'],
        label=entity_dict['type'],
        properties=properties # Store original description and any other fields
    )
    pg_nodes.append(node)

pg_relationships = []
for rel_dict in response_data['relationships']:
    # Ensure all properties are strings or basic types
    properties = {
        # 'description': str(rel_dict.get('description', '')), # The description IS the label here
        'strength': rel_dict.get('strength', 0)
    }
    # The 'label' for a relationship is often its type or verb phrase
    # Here, the 'description' of the relationship itself acts as a good label
    relationship = Relation(
        source_id=rel_dict['source'],
        target_id=rel_dict['target'],
        label=rel_dict['description'], # Using the relationship's description as its type/label
        properties=properties
    )
    pg_relationships.append(relationship)

# %%
# --- 1. Your Parser Function (from previous answer) ---
def parse_custom_llm_response_to_graph_data(response_text: str):
    # ... (parser code from the previous response)
    entities = []
    relationships = []
    content_keywords_str = None
    if "### start ###" in response_text:
        response_text = response_text.split("### start ###", 1)[1]
    if "###END###" in response_text:
        response_text = response_text.split("###END###", 1)[0]
    response_text = response_text.strip()
    lines = response_text.splitlines()
    value_extractor_regex = r'"(.*?)"'
    for line in lines:
        line = line.strip()
        if not line: continue
        if line.startswith('(') and line.endswith(');'):
            core_content = line[1:-2]
        else:
            print(f"Warning: Skipping malformed line (no parens/semicolon): {line}")
            continue
        all_quoted_values = re.findall(value_extractor_regex, core_content)
        if not all_quoted_values:
            print(f"Warning: Skipping line with no quoted values: {line}")
            continue
        record_type = all_quoted_values[0]
        try:
            if record_type == "entity":
                if len(all_quoted_values) >= 4:
                    entities.append({
                        'name': all_quoted_values[1],
                        'type': all_quoted_values[2],
                        'description': all_quoted_values[3]
                    })
                else: print(f"Warning: Malformed entity line: {line}")
            elif record_type == "relationship":
                if len(all_quoted_values) >= 5:
                    parts = core_content.split('|')
                    strength_str = parts[-1].strip()
                    relationships.append({
                        'source': all_quoted_values[1],
                        'target': all_quoted_values[2],
                        'description': all_quoted_values[3],
                        'keywords': all_quoted_values[4],
                        'strength': int(strength_str)
                    })
                else: print(f"Warning: Malformed relationship line: {line}")
            elif record_type == "content_keywords":
                if len(all_quoted_values) >= 2:
                    content_keywords_str = all_quoted_values[1]
                else: print(f"Warning: Malformed content_keywords line: {line}")
        except (IndexError, ValueError) as e:
            print(f"Warning: Error parsing line '{line}': {e}")
    return {"entities": entities, "relationships": relationships, "content_keywords": content_keywords_str}


# --- 3. Parse the response ---
response_data = parse_custom_llm_response_to_graph_data(response.message.content)

print(f"Parsed: {len(response_data['entities'])} entities and {len(response_data['relationships'])} relationships.")
if response_data['entities']:
    print(f"First parsed entity: {response_data['entities'][0]}")
if response_data['relationships']:
    print(f"First parsed relationship: {response_data['relationships'][0]}")


# --- 4. Convert parsed data to PropertyGraphNode and PropertyGraphRelationship objects ---
pg_nodes = []
for entity_dict in response_data['entities']:
    # 'name' becomes id_, 'type' becomes label for the PropertyGraphNode
    # 'description' goes into properties
    node = EntityNode(
        name=entity_dict['name'],        # Unique ID for the node
        label=entity_dict['type'],      # Type of the node (e.g., "symptom", "procedure")
        properties={
            "description": entity_dict['description']
            # You can add other original fields here if needed, e.g.
            # "original_name": entity_dict['name'] # if id_ might be transformed
        }
    )
    pg_nodes.append(node)

pg_relationships = []
for rel_dict in response_data['relationships']:
    # 'description' of the relationship becomes its label (type)
    # 'strength' and 'keywords' go into properties
    # Note: The 'description' from your parsed relationship data is often a full sentence.
    # For PropertyGraphRelationship, the 'label' is typically a concise relationship type
    # (e.g., "CAUSES", "INDICATES", "PART_OF"). If you have a more concise relationship
    # type available or can derive one, that might be better for the 'label'.
    # For now, we'll use the provided 'description' as the label as per your previous structure.
    relationship = Relation(
        source_id=rel_dict['source'],
        target_id=rel_dict['target'],
        label=rel_dict['keywords'], # Using the descriptive text as the relationship label
        properties={
            "strength": rel_dict.get('strength', 0), # Default to 0 if not present
            "keywords": rel_dict.get('description', "")  # Default to empty string
        }
    )
    pg_relationships.append(relationship)

print(f"\nConverted to {len(pg_nodes)} PropertyGraphNodes and {len(pg_relationships)} PropertyGraphRelationships.")
if pg_nodes:
    print(f"First PropertyGraphNode: {pg_nodes[0]}")
if pg_relationships:
    print(f"First PropertyGraphRelationship: {pg_relationships[0]}")

# --- 5. Initialize a PropertyGraphStore ---
graph_store = SimplePropertyGraphStore()

# --- 6. Add nodes and relationships to the graph store ---
graph_store.upsert_nodes(pg_nodes)
graph_store.upsert_relations(pg_relationships)
print("\nNodes and relationships added to SimplePropertyGraphStore.")

# --- 7. Create the PropertyGraphIndex from the existing graph store ---
index = PropertyGraphIndex.from_existing(
    property_graph_store=graph_store,
    llm=llm,
    embed_kg_nodes=False
)
print("PropertyGraphIndex created successfully.")

# --- 8. Query the index ---
if Settings.llm: # Only query if LLM is configured
    query_engine = index.as_query_engine(include_text=False)
    print("\n--- Example Queries ---")
    queries = [
        "What is 'Not Breathing Normally'?",
        "What are the characteristics of an 'Unconscious Adult'?",
        "What procedure is related to 'Unconscious Adult' when they are 'Not Breathing Normally'?",
        "What is the relationship between CPR and a Defibrillator?"
    ]
    for q_text in queries:
        print(f"\nQuery: {q_text}")
        try:
            response = query_engine.query(q_text)
            print(f"Response: {response}")
        except Exception as e:
            print(f"Error during query: {e}")
else:
    print("\nSkipping queries as LLM is not configured.")

# You can also inspect the schema the index has inferred/stored
print("\n--- Graph Schema ---")
try:
    schema = index.get_schema(refresh=False) # Get cached schema
    print(schema)
except Exception as e:
    print(f"Could not retrieve schema: {e}")
# Out:
# Warning: Skipping malformed line (no parens/semicolon): ("content_keywords"|"cardiac arrest response, CPR protocol, airway management, drowning response, emergency response coordination, early defibrillation, resuscitation effectiveness")
# Parsed: 15 entities and 9 relationships.
# First parsed entity: {'name': 'Unconscious Adult', 'type': 'patient_characteristic', 'description': 'An adult patient who is unresponsive to stimuli, indicating a critical emergency requiring immediate intervention and rapid resuscitation efforts.'}
# First parsed relationship: {'source': 'Unconscious Adult', 'target': 'Not Breathing Normally', 'description': 'These two conditions frequently occur together in cardiac arrest situations, initiating the need for immediate CPR.', 'keywords': 'cardiac arrest, resuscitation trigger, critical condition', 'strength': 10}
#
# Converted to 15 PropertyGraphNodes and 9 PropertyGraphRelationships.
# First PropertyGraphNode: Unconscious Adult ({'description': 'An adult patient who is unresponsive to stimuli, indicating a critical emergency requiring immediate intervention and rapid resuscitation efforts.'})
# First PropertyGraphRelationship: cardiac arrest, resuscitation trigger, critical condition ({'strength': 10, 'keywords': 'These two conditions frequently occur together in cardiac arrest situations, initiating the need for immediate CPR.'})
#
# Nodes and relationships added to SimplePropertyGraphStore.
# PropertyGraphIndex created successfully.
#
# --- Example Queries ---
#
# Query: What is 'Not Breathing Normally'?
# Response: Empty Response
#
# Query: What are the characteristics of an 'Unconscious Adult'?
# Response: Empty Response
#
# Query: What procedure is related to 'Unconscious Adult' when they are 'Not Breathing Normally'?
# Response: Empty Response
#
# Query: What is the relationship between CPR and a Defibrillator?
# Error during query: Error code: 400 - {'error': {'message': "Unsupported value: 'messages[0].role' does not support 'system' with this model.", 'type': 'invalid_request_error', 'param': 'messages[0].role', 'code': 'unsupported_value'}}
#
# --- Graph Schema ---
# Could not retrieve schema: 'PropertyGraphIndex' object has no attribute 'get_schema'

# %%
index.property_graph_store.save_networkx_graph(name="./kg_manual2.html")

# %%
print(f"Converted to {len(pg_nodes)} PropertyGraphNodes and {len(pg_relationships)} PropertyGraphRelationships.")
# Out:
# Converted to 12 PropertyGraphNodes and 13 PropertyGraphRelationships.

# %%
graph_store = SimplePropertyGraphStore()
graph_store.upsert_nodes(pg_nodes)
graph_store.upsert_relations(pg_relationships)

print("Nodes and relationships added to SimplePropertyGraphStore.")
# Out:
# Nodes and relationships added to SimplePropertyGraphStore.

# %%
index = PropertyGraphIndex.from_existing(
    property_graph_store=graph_store,
    llm=llm,  # Use the same LLM for querying and embedding
    embed_kg_nodes=False  # Use the same embedding model for consistency
    # If you had original text Documents from which these entities/relationships were extracted,
    # you could pass them as `nodes` (List[BaseNode]) here to also build a vector index component.
    # For now, we're focusing on the graph structure you've already extracted.
)
print("PropertyGraphIndex created successfully.")
# Out:
# PropertyGraphIndex created successfully.

# %%
index.property_graph_store.save_networkx_graph(name="./kg_manual.html")

# %%
query_engine = index.as_query_engine(
    # llm=Settings.llm, # Not needed here if already in global Settings
    include_text=False, # Set to False if you ONLY want to query the graph structure
                        # and don't have associated text chunks in a vector store component.
                        # If you had passed `nodes` (text documents) during index creation,
                        # you might set this to True (or leave default) for hybrid search.
    # For more control, you can pass property_graph_tool_kwargs
    # property_graph_tool_kwargs={"graph_schema_output_parser": KGPropertyGraphQuery()} # if you need more control
)

# %%
Settings.llm = llm

# %%
from llama_index.core.indices.property_graph import SimpleLLMPathExtractor, DynamicLLMPathExtractor
from typing import List, Tuple, Dict, Any, Optional
import re

def parse_fn(response_str: str) -> List[Tuple[str, str, str]]:
    """Parse the structured output from the CoT prompt into triples.
    
    Args:
        response_str: The output string from the LLM
        
    Returns:
        List of triples in (subject, predicate, object) format
    """
    # Define the delimiters (same as in the prompt)
    tuple_delimiter = r"\{tuple_delimiter\}"
    record_delimiter = r"\{record_delimiter\}"
    completion_delimiter = r"\{completion_delimiter\}"
    
    # Clean up the response string
    response_str = response_str.replace(completion_delimiter, "").strip()
    
    # Extract records using record delimiter
    records = re.split(record_delimiter, response_str)
    
    triples = []
    
    # Process each record
    for record in records:
        record = record.strip()
        if not record:
            continue
            
        # Check if it's an entity or relationship
        parts = re.split(tuple_delimiter, record.strip('(")'))
        if len(parts) < 3:
            continue
            
        record_type = parts[0]
        
        if record_type == "entity":
            # Entities become self-referential triples with type as predicate
            if len(parts) >= 3:
                entity_name = parts[1].strip()
                entity_type = parts[2].strip()
                triples.append((entity_name, "type", entity_type))
                
                # If there's a description, add it too
                if len(parts) >= 4:
                    description = parts[3].strip()
                    triples.append((entity_name, "description", description))
                    
        elif record_type == "relationship":
            # Relationships become direct triples
            if len(parts) >= 4:
                source = parts[1].strip()
                target = parts[2].strip()
                relation = parts[3].strip()
                triples.append((source, relation, target))
                
                # Also add strength if available
                if len(parts) >= 5:
                    strength = parts[4].strip()
                    triples.append((source + "_to_" + target, "strength", strength))
    
    return triples

# # Create the extractor with our parsing function
kg_extractor = SimpleLLMPathExtractor(
    llm=llm,
    extract_prompt=CoT_prompt_template,
    parse_fn=parse_fn,
    max_paths_per_chunk=50
)


kg_extractor_2 = DynamicLLMPathExtractor(
    llm=llm,
    extract_prompt=CoT_prompt_template,
    num_workers=4,

)

# %%
index = PropertyGraphIndex.from_documents(
    documents,
    # llm=llm,  # Use the wrapped model
    # embed_model=HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2"),
    kg_extractor=kg_extractor,
    show_progress=True,
    embed_kg_nodes=False,
    storage_context=storage_context,  # Use the custom storage context
)
# Out:
# Parsing nodes:   0%|          | 0/3 [00:00<?, ?it/s]
# Extracting paths from text: 100%|██████████| 13/13 [00:29<00:00,  2.24s/it]
# Extracting implicit paths: 100%|██████████| 13/13 [00:00<00:00, 6405.77it/s]

# %%
index.property_graph_store.save_networkx_graph(name="./kg_test2+simpleparcer.html")
